# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
# Successfully installed gdown-4.7.1

# %%
import gdown

url = 'https://drive.google.com/uc?id=1syawlOQLjgMkmA-Ck28VsuAS8JmLdnEf'

output = 'Fraud_Detection_Dataset.csv'

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1syawlOQLjgMkmA-Ck28VsuAS8JmLdnEf
# From (redirected): https://drive.google.com/uc?id=1syawlOQLjgMkmA-Ck28VsuAS8JmLdnEf&confirm=t&uuid=23301d6d-98cf-488e-990b-36c4bc628d9e
# To: /kaggle/working/Fraud_Detection_Dataset.csv
# 100%|██████████| 1.65G/1.65G [00:07<00:00, 218MB/s]
# 'Fraud_Detection_Dataset.csv'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/kaggle/working/Fraud_Detection_Dataset.csv')

# %%
df
# Out:
#          Transaction ID  User ID  Transaction Amount  \
# 0              51595306     9822              163.08
# 1              85052974     4698              430.74
# 2              23954324     8666              415.74
# 3              44108303     9012              565.89
# 4              66622683     5185              955.49
# ...                 ...      ...                 ...
# 5999995        61037029     7480              448.99
# 5999996        56515851     5636              841.39
# 5999997        66863972     5554              197.28
# 5999998        13449701     1275              358.33
# 5999999        89299426     5418              655.09
#
#         Transaction Date and Time  Merchant ID Payment Method Country Code  \
# 0             2023-01-02 07:47:54         4044   ACH Transfer          KOR
# 1             2021-09-12 15:15:41         4576      2Checkout          VNM
# 2             2023-01-12 17:25:58         4629  Google Wallet          MEX
# 3             2021-02-27 11:31:00         3322          Check          SGP
# 4             2022-09-24 04:06:38         7609       Worldpay          HKG
# ...                           ...          ...            ...          ...
# 5999995       2021-10-20 15:56:32         3346       Discover          SGP
# 5999996       2021-06-14 02:10:00         8415         Alipay          ZAF
# 5999997       2021-11-06 22:33:19         4231       Afterpay          CAN
# 5999998       2022-03-13 15:02:35         9614            JCB           UK
# 5999999       2022-10-20 12:04:27         7515       Payoneer          QAT
#
#         Transaction Type                  Device Type       IP Address  ...  \
# 0                Charity                   GPS Device    42.23.223.120  ...
# 1               Cashback               Medical Device    39.52.212.120  ...
# 2                 Reward  Vehicle Infotainment System   243.180.236.29  ...
# 3               Purchase                        Kiosk   212.186.227.14  ...
# 4            Acquisition                 Smart Mirror   166.113.10.199  ...
# ...                  ...                          ...              ...  ...
# 5999995      Scholarship                       Server  255.134.160.201  ...
# 5999996             Loan               Digital Camera     48.190.84.14  ...
# 5999997   Service Charge              Barcode Scanner      7.21.196.39  ...
# 5999998             Fine                        Robot  211.202.242.100  ...
# 5999999           Refund              Smart Appliance   44.101.127.186  ...
#
#         User's Transaction History Merchant's Reputation Score  \
# 0                               26                        2.71
# 1                               60                        3.95
# 2                               81                        3.81
# 3                               18                        2.67
# 4                               98                        3.19
# ...                            ...                         ...
# 5999995                         34                        2.78
# 5999996                         80                        2.60
# 5999997                         12                        1.35
# 5999998                         57                        1.29
# 5999999                         57                        2.35
#
#         User's Device Location  Transaction Currency    Transaction Purpose  \
# 0               United Kingdom                   NOK       Consultation Fee
# 1                       Mexico                   EGP        Cashback Reward
# 2                        Qatar                   MXN            Acquisition
# 3                        Spain                   CLP         Loan Repayment
# 4                       Israel                   RUB  Dividend Reinvestment
# ...                        ...                   ...                    ...
# 5999995                 Russia                   CHF        Invoice Payment
# 5999996               Malaysia                   HUF             Membership
# 5999997                  Egypt                   HKD              Admission
# 5999998                  China                   AED  Expense Reimbursement
# 5999999            New Zealand                   NOK         Rental Payment
#
#          User's Credit Score User's Email Domain Merchant's Business Age  \
# 0                        343           cox.co.uk                       3
# 1                        688           gmail.com                      13
# 2                        371      rocketmail.com                       7
# 3                        687    roadrunner.co.uk                      15
# 4                        605    protonmail.co.uk                      17
# ...                      ...                 ...                     ...
# 5999995                  679             aim.com                      14
# 5999996                  706             cox.net                      10
# 5999997                  310          live.co.uk                      14
# 5999998                  460      rediffmail.com                      16
# 5999999                  340          live.co.uk                       4
#
#         Transaction Authentication Method  Fraudulent Flag
# 0                Bluetooth Authentication                0
# 1                                 NFC Tag                1
# 2                                   Token                1
# 3                          Time-Based OTP                1
# 4                                Password                1
# ...                                   ...              ...
# 5999995                       Retina Scan                0
# 5999996                Social Media Login                1
# 5999997           Mobile App Notification                0
# 5999998                Authentication App                0
# 5999999                          Password                1
#
# [6000000 rows x 32 columns]

# %% [markdown]
# Due to limited RAM resources on my Kaggle cloud environment, I needed to work with a smaller subset of the original dataset. To achieve this, I randomly sampled a portion of the dataset. This subset, which contains a fraction of the total data, was chosen so that it could fit comfortably within the available memory.
#
#  This downsized dataset allows me to perform various tasks, including data exploration, model development, and testing, without encountering memory-related issues. While the sampled dataset is smaller, it still maintains the essential characteristics of the full dataset, making it suitable for prototyping and experimentation

# %%
# Specify the number of samples for training and testing
train_size = 60000
test_size = 60000

# To Check if the dataset has enough samples
if len(df) < (train_size + test_size):
    raise ValueError("Not enough samples in the dataset for the specified train and test sizes.")

# Create the training sample by slicing the first 'train_size' samples
train_sample = df[:train_size]

# Create the testing sample by slicing the next 'test_size' samples
test_sample = df[train_size:train_size+test_size]

# save the sample data to new CSV files
train_sample.to_csv('train_sample.csv', index=False)
test_sample.to_csv('test_sample.csv', index=False)

# %%
train_df = pd.read_csv('/kaggle/working/train_sample.csv')
test_df = pd.read_csv ('/kaggle/working/test_sample.csv')

# %%
train_df
# Out:
#        Transaction ID  User ID  Transaction Amount Transaction Date and Time  \
# 0            51595306     9822              163.08       2023-01-02 07:47:54
# 1            85052974     4698              430.74       2021-09-12 15:15:41
# 2            23954324     8666              415.74       2023-01-12 17:25:58
# 3            44108303     9012              565.89       2021-02-27 11:31:00
# 4            66622683     5185              955.49       2022-09-24 04:06:38
# ...               ...      ...                 ...                       ...
# 59995        15897278     3856                7.82       2022-02-18 23:51:43
# 59996        49545040     8997              418.72       2022-04-12 21:02:28
# 59997        68379028     1664              882.16       2023-05-25 05:39:06
# 59998        29067316     3325              143.11       2023-03-29 15:56:40
# 59999        89748174     5240              895.65       2021-01-01 06:21:02
#
#        Merchant ID Payment Method Country Code Transaction Type  \
# 0             4044   ACH Transfer          KOR          Charity
# 1             4576      2Checkout          VNM         Cashback
# 2             4629  Google Wallet          MEX           Reward
# 3             3322          Check          SGP         Purchase
# 4             7609       Worldpay          HKG      Acquisition
# ...            ...            ...          ...              ...
# 59995         5913          Check          ITA             Loan
# 59996         9556           Cash          ARG    Reimbursement
# 59997         4843           Cash          HKG     Compensation
# 59998         3895     Debit Card          IND          Charity
# 59999         8126  Western Union          AUT           Rental
#
#                        Device Type      IP Address  ...  \
# 0                       GPS Device   42.23.223.120  ...
# 1                   Medical Device   39.52.212.120  ...
# 2      Vehicle Infotainment System  243.180.236.29  ...
# 3                            Kiosk  212.186.227.14  ...
# 4                     Smart Mirror  166.113.10.199  ...
# ...                            ...             ...  ...
# 59995        Industrial Controller     6.244.14.65  ...
# 59996         Home Security System  246.61.109.217  ...
# 59997                   Smartwatch  144.130.16.105  ...
# 59998        Industrial Controller  149.80.189.157  ...
# 59999               Digital Camera   180.63.140.29  ...
#
#       User's Transaction History Merchant's Reputation Score  \
# 0                             26                        2.71
# 1                             60                        3.95
# 2                             81                        3.81
# 3                             18                        2.67
# 4                             98                        3.19
# ...                          ...                         ...
# 59995                         25                        1.31
# 59996                         67                        3.48
# 59997                         33                        1.90
# 59998                         82                        3.15
# 59999                         52                        3.50
#
#       User's Device Location  Transaction Currency    Transaction Purpose  \
# 0             United Kingdom                   NOK       Consultation Fee
# 1                     Mexico                   EGP        Cashback Reward
# 2                      Qatar                   MXN            Acquisition
# 3                      Spain                   CLP         Loan Repayment
# 4                     Israel                   RUB  Dividend Reinvestment
# ...                      ...                   ...                    ...
# 59995                  Italy                   ILS            Auction Bid
# 59996                  China                   SAR        Retail Purchase
# 59997              Argentina                   HUF              Admission
# 59998                 Taiwan                   CHF                 Payout
# 59999              Hong Kong                   CZK       Product Purchase
#
#        User's Credit Score User's Email Domain Merchant's Business Age  \
# 0                      343           cox.co.uk                       3
# 1                      688           gmail.com                      13
# 2                      371      rocketmail.com                       7
# 3                      687    roadrunner.co.uk                      15
# 4                      605    protonmail.co.uk                      17
# ...                    ...                 ...                     ...
# 59995                  476            live.com                      19
# 59996                  709       verizon.co.uk                      10
# 59997                  467          yandex.com                      11
# 59998                  837       outlook.co.uk                       6
# 59999                  684           aim.co.uk                       2
#
#       Transaction Authentication Method  Fraudulent Flag
# 0              Bluetooth Authentication                0
# 1                               NFC Tag                1
# 2                                 Token                1
# 3                        Time-Based OTP                1
# 4                              Password                1
# ...                                 ...              ...
# 59995                    Time-Based OTP                0
# 59996                           Face ID                1
# 59997                           QR Code                0
# 59998                           QR Code                0
# 59999                          Password                0
#
# [60000 rows x 32 columns]

# %%
test_df
# Out:
#        Transaction ID  User ID  Transaction Amount Transaction Date and Time  \
# 0            69414003     9939              929.19       2022-04-08 13:14:54
# 1            49235678     8112              403.19       2021-07-23 22:02:18
# 2            40696190     4844              669.28       2021-11-21 18:36:11
# 3            52083541     8862              558.31       2022-01-26 19:41:21
# 4            12933782     2687              691.77       2021-07-04 11:56:34
# ...               ...      ...                 ...                       ...
# 59995        71652081     4455              519.72       2023-01-21 16:08:53
# 59996        28744902     8455              957.31       2021-04-29 13:00:33
# 59997        42650837     3826              783.36       2023-06-01 13:01:56
# 59998        96541074     6937              983.64       2022-06-01 03:00:52
# 59999        32591469     8715              942.46       2022-02-26 10:31:11
#
#        Merchant ID         Payment Method Country Code Transaction Type  \
# 0             1091               Discover          QAT         Donation
# 1             7760                 Klarna           UK         Transfer
# 2             8096               Discover          NOR              Tax
# 3             2397                 Stripe          IND     Contribution
# 4             2849                 Klarna          NOR       Settlement
# ...            ...                    ...          ...              ...
# 59995         3721                 Skrill          KOR          Buyback
# 59996         3544  Cryptocurrency Wallet          IDN         Transfer
# 59997         5217          Google Wallet          ZAF          Auction
# 59998         7683               Neteller          UAE         Cashback
# 59999         4187          Visa Checkout          TAI         Purchase
#
#                        Device Type       IP Address  ...  \
# 0                         E-Reader   216.97.124.253  ...
# 1                            Kiosk  107.155.189.168  ...
# 2                  Vending Machine      68.74.184.0  ...
# 3                     POS Terminal   182.49.242.200  ...
# 4                       GPS Device     92.93.32.160  ...
# ...                            ...              ...  ...
# 59995                       Laptop  156.220.192.210  ...
# 59996               Gaming Console   223.248.110.39  ...
# 59997  Vehicle Infotainment System    244.55.87.164  ...
# 59998              Vending Machine   122.53.140.151  ...
# 59999               Digital Camera   115.217.211.63  ...
#
#       User's Transaction History Merchant's Reputation Score  \
# 0                             53                        3.77
# 1                              7                        1.07
# 2                             91                        1.92
# 3                             29                        1.18
# 4                             91                        3.77
# ...                          ...                         ...
# 59995                         99                        3.10
# 59996                         49                        4.84
# 59997                         10                        1.15
# 59998                         57                        2.59
# 59999                         50                        2.43
#
#       User's Device Location  Transaction Currency Transaction Purpose  \
# 0       United Arab Emirates                   AED        Compensation
# 1                  Hong Kong                   QAR             Buyback
# 2                  Hong Kong                   TRY     Retail Purchase
# 3                   Malaysia                   RUB     Cashback Reward
# 4                     Poland                   USD         Scholarship
# ...                      ...                   ...                 ...
# 59995                 Canada                   EGP         Acquisition
# 59996                 Turkey                   INR    Registration Fee
# 59997                  Egypt                   VND     Invoice Payment
# 59998                 Greece                   KES  Transfer to Family
# 59999           South Africa                   SAR     Utility Payment
#
#        User's Credit Score User's Email Domain Merchant's Business Age  \
# 0                      638             aol.com                      20
# 1                      338    rocketmail.co.uk                      13
# 2                      384           gmail.com                       1
# 3                      666             aol.com                      15
# 4                      645             aim.com                       3
# ...                    ...                 ...                     ...
# 59995                  549         gmail.co.uk                      10
# 59996                  303      rocketmail.com                       2
# 59997                  721             aol.com                       6
# 59998                  597        tutanota.com                      20
# 59999                  521      roadrunner.com                      11
#
#       Transaction Authentication Method  Fraudulent Flag
# 0      Certificate-based Authentication                1
# 1                Signature Verification                1
# 2                             Iris Scan                1
# 3                     Voice Recognition                1
# 4                               QR Code                0
# ...                                 ...              ...
# 59995                        Voiceprint                0
# 59996                        Smart Card                1
# 59997                           CAPTCHA                1
# 59998              Behavioral Analytics                1
# 59999                 Security Question                0
#
# [60000 rows x 32 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Transaction ID                     60000 non-null  int64
#  1   User ID                            60000 non-null  int64
#  2   Transaction Amount                 60000 non-null  float64
#  3   Transaction Date and Time          60000 non-null  object
#  4   Merchant ID                        60000 non-null  int64
#  5   Payment Method                     60000 non-null  object
#  6   Country Code                       60000 non-null  object
#  7   Transaction Type                   60000 non-null  object
#  8   Device Type                        60000 non-null  object
#  9   IP Address                         60000 non-null  object
#  10  Browser Type                       60000 non-null  object
#  11  Operating System                   60000 non-null  object
#  12  Merchant Category                  60000 non-null  object
#  13  User Age                           60000 non-null  int64
#  14  User Occupation                    60000 non-null  object
#  15  User Income                        60000 non-null  float64
#  16  User Gender                        60000 non-null  object
#  17  User Account Status                60000 non-null  object
#  18  Transaction Status                 60000 non-null  object
#  19  Location Distance                  60000 non-null  float64
#  20  Time Taken for Transaction         60000 non-null  float64
#  21  Transaction Time of Day            60000 non-null  object
#  22  User's Transaction History         60000 non-null  int64
#  23  Merchant's Reputation Score        60000 non-null  float64
#  24  User's Device Location             60000 non-null  object
#  25  Transaction Currency               60000 non-null  object
#  26  Transaction Purpose                60000 non-null  object
#  27  User's Credit Score                60000 non-null  int64
#  28  User's Email Domain                60000 non-null  object
#  29  Merchant's Business Age            60000 non-null  int64
#  30  Transaction Authentication Method  60000 non-null  object
#  31  Fraudulent Flag                    60000 non-null  int64
# dtypes: float64(5), int64(8), object(19)
# memory usage: 14.6+ MB

# %%
# Concatenate the datasets vertically (along rows)
concat_data = pd.concat([train_df, test_df], axis=0)

# Optionally, you can reset the index of the concatenated dataset
concat_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## **Feature Engineering**

# %%
# Convert the "Transaction Date and Time" column to datetime type
concat_data['Transaction Date and Time'] = pd.to_datetime(df['Transaction Date and Time'])

# Extract various datetime components
concat_data['Transaction Year'] = concat_data['Transaction Date and Time'].dt.year
concat_data['Transaction Month'] = concat_data['Transaction Date and Time'].dt.month
concat_data['Transaction Day'] = concat_data['Transaction Date and Time'].dt.day
concat_data['Transaction Hour'] = concat_data['Transaction Date and Time'].dt.hour
concat_data['Transaction Minute'] = concat_data['Transaction Date and Time'].dt.minute
concat_data['Transaction Second'] = concat_data['Transaction Date and Time'].dt.second

concat_data.drop(columns=['Transaction Date and Time'], inplace=True)

# %%
# List of columns to one-hot encode
categorical_columns = ['Payment Method', 'Country Code', 'Transaction Type', 'Device Type',
                       'Browser Type', 'Operating System', 'Merchant Category', 'User Occupation',
                       'User Gender', 'User Account Status', 'Transaction Status',
                       'Transaction Time of Day', "User's Device Location", 'Transaction Currency',
                       'Transaction Purpose', "User's Email Domain", 'Transaction Authentication Method']

# Perform one-hot encoding for the selected columns
concat_data= pd.get_dummies(concat_data, columns=categorical_columns)

# %%
concat_data.drop(['Transaction ID', 'User ID', 'Merchant ID', 'IP Address'], axis=1, inplace=True)

# %%
print(concat_data.dtypes)
# Out:
# Transaction Amount                                                   float64
# User Age                                                               int64
# User Income                                                          float64
# Location Distance                                                    float64
# Time Taken for Transaction                                           float64
#                                                                       ...
# Transaction Authentication Method_Transaction Confirmation Number       bool
# Transaction Authentication Method_Two-Factor Authentication             bool
# Transaction Authentication Method_USB Security Key                      bool
# Transaction Authentication Method_Voice Recognition                     bool
# Transaction Authentication Method_Voiceprint                            bool
# Length: 582, dtype: object

# %%
from sklearn.model_selection import train_test_split

# Load your concatenated data (assuming it's already loaded as 'concatenated_data')

# Split the data into features (X) and target (y)
X = concat_data.drop(columns=['Fraudulent Flag'])  # Features
y = concat_data['Fraudulent Flag']  # Target variable

# Split the data into training and testing sets
test_size = 0.2  # Adjust the test size as needed (e.g., 0.2 for 80% train, 20% test)
random_state = 42  # Set a random seed for reproducibility

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

# Now, you have X_train (features for training), y_train (target for training),
# X_test (features for testing), and y_test (target for testing) ready for model prediction.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Create a Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on the training data
rf_model.fit(X_train, y_train)

# Make predictions on the test data
rf_predictions = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, rf_predictions)
print(f"Accuracy: {accuracy:.2f}")

# Generate a classification report
class_report = classification_report(y_test, rf_predictions)
print("Classification Report:\n", class_report)

# Create a confusion matrix
conf_matrix = confusion_matrix(y_test, rf_predictions)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.50
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.50      0.50     11923
#            1       0.50      0.49      0.50     12077
#
#     accuracy                           0.50     24000
#    macro avg       0.50      0.50      0.50     24000
# weighted avg       0.50      0.50      0.50     24000
#
# Confusion Matrix:
#  [[5996 5927]
#  [6151 5926]]

# %% [markdown]
# Accuracy: The accuracy of the model is 0.50, which means that it correctly predicted 50% of the total instances in the dataset. Accuracy is the ratio of correctly predicted instances to the total instances.
#
# Classification Report: The classification report provides more detailed information about the model's performance, including precision, recall, and F1-score for each class (0 and 1).
#
# Precision: Precision is the ratio of true positives to the total predicted positives. For class 0, the precision is 0.49, and for class 1, it's 0.50. This indicates how many of the predicted positive cases are actually correct.
#
# Recall: Recall, also known as sensitivity or true positive rate, is the ratio of true positives to the total actual positives. For class 0, the recall is 0.50, and for class 1, it's 0.49. This indicates how many of the actual positive cases were correctly predicted.
#
# F1-Score: The F1-score is the harmonic mean of precision and recall. It provides a balance between precision and recall. For both classes, the F1-score is 0.50.
#
# Support: Support represents the number of instances in each class.
#
# Confusion Matrix: The confusion matrix is a tabular representation of the model's predictions. It shows how many instances were correctly or incorrectly classified.
#
# The top-left value (5996) represents the true negatives (TN), meaning instances correctly classified as class 0.
# The top-right value (5927) represents false positives (FP), meaning instances incorrectly classified as class 1.
# The bottom-left value (6151) represents false negatives (FN), meaning instances incorrectly classified as class 0.
# The bottom-right value (5926) represents true positives (TP), meaning instances correctly classified as class 1.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report


# Create a Logistic Regression model
logistic_regression_model = LogisticRegression(random_state=42)

# Train the model on the training data
logistic_regression_model.fit(X_train, y_train)

# Make predictions on the test data
logistic_regression_predictions = logistic_regression_model.predict(X_test)

# Calculate and print evaluation metrics
accuracy = accuracy_score(y_test, logistic_regression_predictions)
precision = precision_score(y_test, logistic_regression_predictions)
recall = recall_score(y_test, logistic_regression_predictions)
f1 = f1_score(y_test, logistic_regression_predictions)
conf_matrix = confusion_matrix(y_test, logistic_regression_predictions)
class_report = classification_report(y_test, logistic_regression_predictions)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.50
# Precision: 0.50
# Recall: 1.00
# F1-score: 0.67
# Confusion Matrix:
#  [[    0 11923]
#  [    0 12077]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     11923
#            1       0.50      1.00      0.67     12077
#
#     accuracy                           0.50     24000
#    macro avg       0.25      0.50      0.33     24000
# weighted avg       0.25      0.50      0.34     24000

# %% [markdown]
# Accuracy: The accuracy of the model is 0.50, which means that it correctly predicted 50% of the total instances in the dataset. However, accuracy alone doesn't provide a complete picture of the model's performance.
#
# Precision: The precision for class 0 is 0.00, and for class 1, it's 0.50. Precision is a measure of how many of the predicted positive cases are actually correct. In this case, for class 0, there are no true positives (TP), resulting in a precision of 0.00.
#
# Recall: The recall for class 0 is 0.00, and for class 1, it's 1.00. Recall, also known as sensitivity, is the ratio of true positives (TP) to the total actual positives. In this case, for class 0, there are no true positives, leading to a recall of 0.00, while for class 1, all actual positives were correctly predicted, resulting in a recall of 1.00.
#
# F1-Score: The F1-score is the harmonic mean of precision and recall. It provides a balance between precision and recall. For class 0, the F1-score is 0.00, and for class 1, it's 0.67.
#
# Confusion Matrix: The confusion matrix provides details about how the model's predictions compare to the actual class labels.
#
# For class 0, there are no true positives (0) and a high number of false negatives (11923), resulting in the low precision, recall, and F1-score.
# For class 1, there are a high number of true positives (12077) and no false positives, leading to a relatively higher precision, recall, and F1-score.
# Classification Report: The classification report summarizes the model's performance for each class (0 and 1) as well as some overall metrics.
#
# The precision, recall, and F1-score for class 0 are low due to the absence of true positives.
# The precision for class 1 is relatively better because all positive predictions belong to this class.
# The accuracy is 0.50, indicating that the model correctly classified half of the instances, primarily driven by the correct classification of class 1 instances.

# %%
from catboost import CatBoostClassifier

# Create a CatBoostClassifier
catboost_model = CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1, loss_function='Logloss', random_seed=42)

# Train the model on the training data
catboost_model.fit(X_train, y_train)

# Make predictions on the test data
catboost_predictions = catboost_model.predict(X_test)

# Calculate and print evaluation metrics
accuracy = accuracy_score(y_test, catboost_predictions)
conf_matrix = confusion_matrix(y_test, catboost_predictions)
class_report = classification_report(y_test, catboost_predictions)

print(f"Accuracy: {accuracy:.2f}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# 0:	learn: 0.6930375	total: 78.8ms	remaining: 1m 18s
# 1:	learn: 0.6929497	total: 101ms	remaining: 50.5s
# 2:	learn: 0.6928583	total: 122ms	remaining: 40.5s
# 3:	learn: 0.6927699	total: 143ms	remaining: 35.7s
# 4:	learn: 0.6926467	total: 165ms	remaining: 32.8s
# 5:	learn: 0.6925880	total: 186ms	remaining: 30.9s
# 6:	learn: 0.6924867	total: 207ms	remaining: 29.4s
# 7:	learn: 0.6924123	total: 233ms	remaining: 28.8s
# 8:	learn: 0.6923226	total: 257ms	remaining: 28.3s
# 9:	learn: 0.6922397	total: 281ms	remaining: 27.8s
# 10:	learn: 0.6921525	total: 301ms	remaining: 27.1s
# 11:	learn: 0.6920871	total: 326ms	remaining: 26.8s
# 12:	learn: 0.6920156	total: 346ms	remaining: 26.3s
# 13:	learn: 0.6919498	total: 367ms	remaining: 25.8s
# 14:	learn: 0.6918734	total: 391ms	remaining: 25.7s
# 15:	learn: 0.6917876	total: 417ms	remaining: 25.6s
# 16:	learn: 0.6917172	total: 440ms	remaining: 25.4s
# 17:	learn: 0.6916482	total: 461ms	remaining: 25.1s
# 18:	learn: 0.6915587	total: 484ms	remaining: 25s
# 19:	learn: 0.6914848	total: 504ms	remaining: 24.7s
# 20:	learn: 0.6914047	total: 527ms	remaining: 24.6s
# 21:	learn: 0.6913097	total: 550ms	remaining: 24.4s
# 22:	learn: 0.6912035	total: 571ms	remaining: 24.3s
# 23:	learn: 0.6911272	total: 592ms	remaining: 24.1s
# 24:	learn: 0.6910507	total: 614ms	remaining: 24s
# 25:	learn: 0.6909633	total: 638ms	remaining: 23.9s
# 26:	learn: 0.6908768	total: 659ms	remaining: 23.8s
# 27:	learn: 0.6908013	total: 680ms	remaining: 23.6s
# 28:	learn: 0.6907076	total: 704ms	remaining: 23.6s
# 29:	learn: 0.6906433	total: 727ms	remaining: 23.5s
# 30:	learn: 0.6905727	total: 748ms	remaining: 23.4s
# 31:	learn: 0.6904827	total: 768ms	remaining: 23.2s
# 32:	learn: 0.6903735	total: 792ms	remaining: 23.2s
# 33:	learn: 0.6902974	total: 815ms	remaining: 23.2s
# 34:	learn: 0.6902187	total: 838ms	remaining: 23.1s
# 35:	learn: 0.6901611	total: 859ms	remaining: 23s
# 36:	learn: 0.6900661	total: 883ms	remaining: 23s
# 37:	learn: 0.6899786	total: 907ms	remaining: 23s
# 38:	learn: 0.6899215	total: 928ms	remaining: 22.9s
# 39:	learn: 0.6898654	total: 949ms	remaining: 22.8s
# 40:	learn: 0.6897776	total: 971ms	remaining: 22.7s
# 41:	learn: 0.6896750	total: 992ms	remaining: 22.6s
# 42:	learn: 0.6895999	total: 1.01s	remaining: 22.6s
# 43:	learn: 0.6895044	total: 1.04s	remaining: 22.5s
# 44:	learn: 0.6894061	total: 1.06s	remaining: 22.5s
# 45:	learn: 0.6893447	total: 1.08s	remaining: 22.5s
# 46:	learn: 0.6892666	total: 1.11s	remaining: 22.5s
# 47:	learn: 0.6891984	total: 1.13s	remaining: 22.4s
# 48:	learn: 0.6891117	total: 1.15s	remaining: 22.4s
# 49:	learn: 0.6890204	total: 1.18s	remaining: 22.3s
# 50:	learn: 0.6889402	total: 1.2s	remaining: 22.3s
# 51:	learn: 0.6888444	total: 1.22s	remaining: 22.2s
# 52:	learn: 0.6887837	total: 1.24s	remaining: 22.2s
# 53:	learn: 0.6887166	total: 1.26s	remaining: 22.1s
# 54:	learn: 0.6886586	total: 1.28s	remaining: 22s
# 55:	learn: 0.6885766	total: 1.3s	remaining: 22s
# 56:	learn: 0.6884778	total: 1.33s	remaining: 22s
# 57:	learn: 0.6883897	total: 1.35s	remaining: 21.9s
# 58:	learn: 0.6883157	total: 1.37s	remaining: 21.9s
# 59:	learn: 0.6882362	total: 1.4s	remaining: 21.9s
# 60:	learn: 0.6881374	total: 1.42s	remaining: 21.8s
# 61:	learn: 0.6880508	total: 1.44s	remaining: 21.8s
# 62:	learn: 0.6879467	total: 1.47s	remaining: 21.8s
# 63:	learn: 0.6878905	total: 1.49s	remaining: 21.8s
# 64:	learn: 0.6878124	total: 1.51s	remaining: 21.8s
# 65:	learn: 0.6877370	total: 1.53s	remaining: 21.7s
# 66:	learn: 0.6876660	total: 1.56s	remaining: 21.7s
# 67:	learn: 0.6875990	total: 1.58s	remaining: 21.7s
# 68:	learn: 0.6875371	total: 1.6s	remaining: 21.6s
# 69:	learn: 0.6874583	total: 1.62s	remaining: 21.6s
# 70:	learn: 0.6873889	total: 1.65s	remaining: 21.5s
# 71:	learn: 0.6873066	total: 1.67s	remaining: 21.5s
# 72:	learn: 0.6872346	total: 1.69s	remaining: 21.5s
# 73:	learn: 0.6871387	total: 1.72s	remaining: 21.5s
# 74:	learn: 0.6870606	total: 1.74s	remaining: 21.5s
# 75:	learn: 0.6869492	total: 1.76s	remaining: 21.4s
# 76:	learn: 0.6868839	total: 1.78s	remaining: 21.4s
# 77:	learn: 0.6868158	total: 1.8s	remaining: 21.3s
# 78:	learn: 0.6867498	total: 1.83s	remaining: 21.3s
# 79:	learn: 0.6866791	total: 1.85s	remaining: 21.3s
# 80:	learn: 0.6866084	total: 1.88s	remaining: 21.3s
# 81:	learn: 0.6865366	total: 1.9s	remaining: 21.3s
# 82:	learn: 0.6864512	total: 1.92s	remaining: 21.2s
# 83:	learn: 0.6863870	total: 1.94s	remaining: 21.2s
# 84:	learn: 0.6863060	total: 1.97s	remaining: 21.2s
# 85:	learn: 0.6862441	total: 1.99s	remaining: 21.1s
# 86:	learn: 0.6861638	total: 2.01s	remaining: 21.1s
# 87:	learn: 0.6860967	total: 2.04s	remaining: 21.2s
# 88:	learn: 0.6860089	total: 2.07s	remaining: 21.2s
# 89:	learn: 0.6859502	total: 2.09s	remaining: 21.2s
# 90:	learn: 0.6858932	total: 2.12s	remaining: 21.2s
# 91:	learn: 0.6858062	total: 2.15s	remaining: 21.2s
# 92:	learn: 0.6857228	total: 2.19s	remaining: 21.3s
# 93:	learn: 0.6856534	total: 2.22s	remaining: 21.4s
# 94:	learn: 0.6855933	total: 2.24s	remaining: 21.4s
# 95:	learn: 0.6855066	total: 2.26s	remaining: 21.3s
# 96:	learn: 0.6854227	total: 2.29s	remaining: 21.3s
# 97:	learn: 0.6853420	total: 2.31s	remaining: 21.2s
# 98:	learn: 0.6852593	total: 2.33s	remaining: 21.2s
# 99:	learn: 0.6851691	total: 2.35s	remaining: 21.2s
# 100:	learn: 0.6851089	total: 2.37s	remaining: 21.1s
# 101:	learn: 0.6850270	total: 2.4s	remaining: 21.1s
# 102:	learn: 0.6849325	total: 2.42s	remaining: 21.1s
# 103:	learn: 0.6848690	total: 2.45s	remaining: 21.1s
# 104:	learn: 0.6847990	total: 2.47s	remaining: 21.1s
# 105:	learn: 0.6847021	total: 2.49s	remaining: 21s
# 106:	learn: 0.6846067	total: 2.51s	remaining: 21s
# 107:	learn: 0.6845328	total: 2.53s	remaining: 20.9s
# 108:	learn: 0.6844525	total: 2.56s	remaining: 20.9s
# 109:	learn: 0.6843406	total: 2.58s	remaining: 20.9s
# 110:	learn: 0.6842499	total: 2.6s	remaining: 20.8s
# 111:	learn: 0.6841666	total: 2.62s	remaining: 20.8s
# 112:	learn: 0.6840883	total: 2.65s	remaining: 20.8s
# 113:	learn: 0.6840079	total: 2.67s	remaining: 20.7s
# 114:	learn: 0.6839324	total: 2.69s	remaining: 20.7s
# 115:	learn: 0.6838561	total: 2.71s	remaining: 20.7s
# 116:	learn: 0.6837448	total: 2.73s	remaining: 20.6s
# 117:	learn: 0.6836431	total: 2.75s	remaining: 20.6s
# 118:	learn: 0.6835517	total: 2.77s	remaining: 20.5s
# 119:	learn: 0.6834355	total: 2.8s	remaining: 20.5s
# 120:	learn: 0.6833620	total: 2.82s	remaining: 20.5s
# 121:	learn: 0.6832841	total: 2.84s	remaining: 20.4s
# 122:	learn: 0.6831586	total: 2.86s	remaining: 20.4s
# 123:	learn: 0.6830208	total: 2.88s	remaining: 20.4s
# 124:	learn: 0.6828945	total: 2.91s	remaining: 20.3s
# 125:	learn: 0.6828214	total: 2.93s	remaining: 20.3s
# 126:	learn: 0.6827245	total: 2.95s	remaining: 20.3s
# 127:	learn: 0.6826296	total: 2.97s	remaining: 20.3s
# 128:	learn: 0.6825216	total: 3s	remaining: 20.2s
# 129:	learn: 0.6824339	total: 3.02s	remaining: 20.2s
# 130:	learn: 0.6823424	total: 3.04s	remaining: 20.1s
# 131:	learn: 0.6822512	total: 3.06s	remaining: 20.1s
# 132:	learn: 0.6821384	total: 3.08s	remaining: 20.1s
# 133:	learn: 0.6820187	total: 3.1s	remaining: 20.1s
# 134:	learn: 0.6819006	total: 3.12s	remaining: 20s
# 135:	learn: 0.6817976	total: 3.14s	remaining: 20s
# 136:	learn: 0.6816900	total: 3.17s	remaining: 20s
# 137:	learn: 0.6815925	total: 3.19s	remaining: 19.9s
# 138:	learn: 0.6815107	total: 3.21s	remaining: 19.9s
# 139:	learn: 0.6813892	total: 3.23s	remaining: 19.9s
# 140:	learn: 0.6813008	total: 3.25s	remaining: 19.8s
# 141:	learn: 0.6812058	total: 3.28s	remaining: 19.8s
# 142:	learn: 0.6811176	total: 3.3s	remaining: 19.8s
# 143:	learn: 0.6809749	total: 3.32s	remaining: 19.8s
# 144:	learn: 0.6808707	total: 3.35s	remaining: 19.7s
# 145:	learn: 0.6807603	total: 3.37s	remaining: 19.7s
# 146:	learn: 0.6806683	total: 3.39s	remaining: 19.7s
# 147:	learn: 0.6805609	total: 3.41s	remaining: 19.7s
# 148:	learn: 0.6804311	total: 3.44s	remaining: 19.6s
# 149:	learn: 0.6802849	total: 3.46s	remaining: 19.6s
# 150:	learn: 0.6801818	total: 3.48s	remaining: 19.6s
# 151:	learn: 0.6800874	total: 3.5s	remaining: 19.5s
# 152:	learn: 0.6799785	total: 3.52s	remaining: 19.5s
# 153:	learn: 0.6798606	total: 3.54s	remaining: 19.5s
# 154:	learn: 0.6797334	total: 3.56s	remaining: 19.4s
# 155:	learn: 0.6796486	total: 3.58s	remaining: 19.4s
# 156:	learn: 0.6795534	total: 3.61s	remaining: 19.4s
# 157:	learn: 0.6794610	total: 3.63s	remaining: 19.3s
# 158:	learn: 0.6793580	total: 3.65s	remaining: 19.3s
# 159:	learn: 0.6792634	total: 3.67s	remaining: 19.3s
# 160:	learn: 0.6791580	total: 3.69s	remaining: 19.3s
# 161:	learn: 0.6790688	total: 3.71s	remaining: 19.2s
# 162:	learn: 0.6789578	total: 3.74s	remaining: 19.2s
# 163:	learn: 0.6788354	total: 3.76s	remaining: 19.2s
# 164:	learn: 0.6787166	total: 3.78s	remaining: 19.1s
# 165:	learn: 0.6786110	total: 3.8s	remaining: 19.1s
# 166:	learn: 0.6784863	total: 3.83s	remaining: 19.1s
# 167:	learn: 0.6783753	total: 3.85s	remaining: 19.1s
# 168:	learn: 0.6782569	total: 3.87s	remaining: 19s
# 169:	learn: 0.6781491	total: 3.89s	remaining: 19s
# 170:	learn: 0.6780440	total: 3.92s	remaining: 19s
# 171:	learn: 0.6779108	total: 3.94s	remaining: 19s
# 172:	learn: 0.6777969	total: 3.96s	remaining: 18.9s
# 173:	learn: 0.6776961	total: 3.98s	remaining: 18.9s
# 174:	learn: 0.6775910	total: 4s	remaining: 18.9s
# 175:	learn: 0.6775008	total: 4.02s	remaining: 18.8s
# 176:	learn: 0.6773961	total: 4.05s	remaining: 18.8s
# 177:	learn: 0.6772828	total: 4.07s	remaining: 18.8s
# 178:	learn: 0.6771657	total: 4.09s	remaining: 18.8s
# 179:	learn: 0.6771014	total: 4.11s	remaining: 18.7s
# 180:	learn: 0.6770090	total: 4.14s	remaining: 18.7s
# 181:	learn: 0.6769133	total: 4.16s	remaining: 18.7s
# 182:	learn: 0.6768168	total: 4.18s	remaining: 18.7s
# 183:	learn: 0.6767008	total: 4.2s	remaining: 18.6s
# 184:	learn: 0.6765783	total: 4.23s	remaining: 18.6s
# 185:	learn: 0.6764966	total: 4.25s	remaining: 18.6s
# 186:	learn: 0.6763975	total: 4.27s	remaining: 18.6s
# 187:	learn: 0.6763077	total: 4.29s	remaining: 18.5s
# 188:	learn: 0.6762354	total: 4.31s	remaining: 18.5s
# 189:	learn: 0.6761183	total: 4.33s	remaining: 18.5s
# 190:	learn: 0.6760163	total: 4.35s	remaining: 18.4s
# 191:	learn: 0.6759230	total: 4.38s	remaining: 18.4s
# 192:	learn: 0.6757962	total: 4.4s	remaining: 18.4s
# 193:	learn: 0.6757004	total: 4.42s	remaining: 18.4s
# 194:	learn: 0.6755781	total: 4.45s	remaining: 18.4s
# 195:	learn: 0.6754867	total: 4.47s	remaining: 18.4s
# 196:	learn: 0.6753866	total: 4.5s	remaining: 18.3s
# 197:	learn: 0.6752572	total: 4.52s	remaining: 18.3s
# 198:	learn: 0.6751446	total: 4.54s	remaining: 18.3s
# 199:	learn: 0.6750504	total: 4.56s	remaining: 18.3s
# 200:	learn: 0.6749484	total: 4.58s	remaining: 18.2s
# 201:	learn: 0.6748442	total: 4.61s	remaining: 18.2s
# 202:	learn: 0.6747430	total: 4.63s	remaining: 18.2s
# 203:	learn: 0.6746383	total: 4.65s	remaining: 18.1s
# 204:	learn: 0.6745190	total: 4.68s	remaining: 18.1s
# 205:	learn: 0.6744314	total: 4.7s	remaining: 18.1s
# 206:	learn: 0.6743343	total: 4.72s	remaining: 18.1s
# 207:	learn: 0.6742296	total: 4.74s	remaining: 18.1s
# 208:	learn: 0.6741173	total: 4.76s	remaining: 18s
# 209:	learn: 0.6740115	total: 4.79s	remaining: 18s
# 210:	learn: 0.6739019	total: 4.81s	remaining: 18s
# 211:	learn: 0.6738140	total: 4.83s	remaining: 18s
# 212:	learn: 0.6737172	total: 4.85s	remaining: 17.9s
# 213:	learn: 0.6736080	total: 4.88s	remaining: 17.9s
# 214:	learn: 0.6735147	total: 4.9s	remaining: 17.9s
# 215:	learn: 0.6733837	total: 4.92s	remaining: 17.9s
# 216:	learn: 0.6732742	total: 4.95s	remaining: 17.8s
# 217:	learn: 0.6731685	total: 4.97s	remaining: 17.8s
# 218:	learn: 0.6730687	total: 4.99s	remaining: 17.8s
# 219:	learn: 0.6729626	total: 5.01s	remaining: 17.8s
# 220:	learn: 0.6728773	total: 5.04s	remaining: 17.8s
# 221:	learn: 0.6727654	total: 5.06s	remaining: 17.7s
# 222:	learn: 0.6726291	total: 5.08s	remaining: 17.7s
# 223:	learn: 0.6725210	total: 5.11s	remaining: 17.7s
# 224:	learn: 0.6724363	total: 5.13s	remaining: 17.7s
# 225:	learn: 0.6723409	total: 5.15s	remaining: 17.6s
# 226:	learn: 0.6722409	total: 5.17s	remaining: 17.6s
# 227:	learn: 0.6721303	total: 5.19s	remaining: 17.6s
# 228:	learn: 0.6720323	total: 5.21s	remaining: 17.6s
# 229:	learn: 0.6719372	total: 5.24s	remaining: 17.5s
# 230:	learn: 0.6718427	total: 5.26s	remaining: 17.5s
# 231:	learn: 0.6717451	total: 5.28s	remaining: 17.5s
# 232:	learn: 0.6716104	total: 5.3s	remaining: 17.4s
# 233:	learn: 0.6715074	total: 5.32s	remaining: 17.4s
# 234:	learn: 0.6713852	total: 5.35s	remaining: 17.4s
# 235:	learn: 0.6712755	total: 5.37s	remaining: 17.4s
# 236:	learn: 0.6711909	total: 5.4s	remaining: 17.4s
# 237:	learn: 0.6710929	total: 5.42s	remaining: 17.4s
# 238:	learn: 0.6710012	total: 5.44s	remaining: 17.3s
# 239:	learn: 0.6708991	total: 5.47s	remaining: 17.3s
# 240:	learn: 0.6707829	total: 5.49s	remaining: 17.3s
# 241:	learn: 0.6706777	total: 5.51s	remaining: 17.3s
# 242:	learn: 0.6705935	total: 5.53s	remaining: 17.2s
# 243:	learn: 0.6705040	total: 5.55s	remaining: 17.2s
# 244:	learn: 0.6703934	total: 5.58s	remaining: 17.2s
# 245:	learn: 0.6703051	total: 5.6s	remaining: 17.2s
# 246:	learn: 0.6701888	total: 5.62s	remaining: 17.1s
# 247:	learn: 0.6700918	total: 5.64s	remaining: 17.1s
# 248:	learn: 0.6700180	total: 5.66s	remaining: 17.1s
# 249:	learn: 0.6699121	total: 5.68s	remaining: 17.1s
# 250:	learn: 0.6697995	total: 5.71s	remaining: 17s
# 251:	learn: 0.6697059	total: 5.73s	remaining: 17s
# 252:	learn: 0.6695884	total: 5.76s	remaining: 17s
# 253:	learn: 0.6694816	total: 5.78s	remaining: 17s
# 254:	learn: 0.6693937	total: 5.8s	remaining: 16.9s
# 255:	learn: 0.6692877	total: 5.82s	remaining: 16.9s
# 256:	learn: 0.6691829	total: 5.84s	remaining: 16.9s
# 257:	learn: 0.6690883	total: 5.87s	remaining: 16.9s
# 258:	learn: 0.6689935	total: 5.89s	remaining: 16.9s
# 259:	learn: 0.6689051	total: 5.91s	remaining: 16.8s
# 260:	learn: 0.6687908	total: 5.93s	remaining: 16.8s
# 261:	learn: 0.6686970	total: 5.96s	remaining: 16.8s
# 262:	learn: 0.6685924	total: 5.98s	remaining: 16.8s
# 263:	learn: 0.6684882	total: 6s	remaining: 16.7s
# 264:	learn: 0.6683896	total: 6.02s	remaining: 16.7s
# 265:	learn: 0.6682801	total: 6.04s	remaining: 16.7s
# 266:	learn: 0.6681545	total: 6.07s	remaining: 16.7s
# 267:	learn: 0.6680671	total: 6.08s	remaining: 16.6s
# 268:	learn: 0.6679503	total: 6.11s	remaining: 16.6s
# 269:	learn: 0.6678186	total: 6.13s	remaining: 16.6s
# 270:	learn: 0.6676906	total: 6.15s	remaining: 16.6s
# 271:	learn: 0.6676104	total: 6.18s	remaining: 16.5s
# 272:	learn: 0.6674942	total: 6.2s	remaining: 16.5s
# 273:	learn: 0.6673888	total: 6.22s	remaining: 16.5s
# 274:	learn: 0.6672960	total: 6.25s	remaining: 16.5s
# 275:	learn: 0.6672129	total: 6.27s	remaining: 16.4s
# 276:	learn: 0.6671178	total: 6.29s	remaining: 16.4s
# 277:	learn: 0.6670292	total: 6.31s	remaining: 16.4s
# 278:	learn: 0.6669161	total: 6.33s	remaining: 16.4s
# 279:	learn: 0.6668129	total: 6.36s	remaining: 16.3s
# 280:	learn: 0.6667123	total: 6.38s	remaining: 16.3s
# 281:	learn: 0.6666092	total: 6.4s	remaining: 16.3s
# 282:	learn: 0.6665207	total: 6.42s	remaining: 16.3s
# 283:	learn: 0.6664476	total: 6.45s	remaining: 16.3s
# 284:	learn: 0.6663478	total: 6.47s	remaining: 16.2s
# 285:	learn: 0.6662092	total: 6.49s	remaining: 16.2s
# 286:	learn: 0.6661067	total: 6.51s	remaining: 16.2s
# 287:	learn: 0.6660091	total: 6.53s	remaining: 16.2s
# 288:	learn: 0.6659148	total: 6.55s	remaining: 16.1s
# 289:	learn: 0.6658152	total: 6.57s	remaining: 16.1s
# 290:	learn: 0.6657204	total: 6.6s	remaining: 16.1s
# 291:	learn: 0.6656324	total: 6.62s	remaining: 16.1s
# 292:	learn: 0.6655383	total: 6.64s	remaining: 16s
# 293:	learn: 0.6654397	total: 6.67s	remaining: 16s
# 294:	learn: 0.6653466	total: 6.69s	remaining: 16s
# 295:	learn: 0.6652445	total: 6.71s	remaining: 15.9s
# 296:	learn: 0.6651477	total: 6.73s	remaining: 15.9s
# 297:	learn: 0.6650705	total: 6.75s	remaining: 15.9s
# 298:	learn: 0.6649626	total: 6.77s	remaining: 15.9s
# 299:	learn: 0.6648372	total: 6.8s	remaining: 15.9s
# 300:	learn: 0.6647346	total: 6.82s	remaining: 15.8s
# 301:	learn: 0.6646341	total: 6.84s	remaining: 15.8s
# 302:	learn: 0.6645541	total: 6.86s	remaining: 15.8s
# 303:	learn: 0.6644624	total: 6.88s	remaining: 15.8s
# 304:	learn: 0.6643573	total: 6.91s	remaining: 15.7s
# 305:	learn: 0.6642694	total: 6.93s	remaining: 15.7s
# 306:	learn: 0.6641694	total: 6.95s	remaining: 15.7s
# 307:	learn: 0.6640498	total: 6.97s	remaining: 15.7s
# 308:	learn: 0.6639411	total: 7s	remaining: 15.7s
# 309:	learn: 0.6638467	total: 7.03s	remaining: 15.6s
# 310:	learn: 0.6637316	total: 7.05s	remaining: 15.6s
# 311:	learn: 0.6636298	total: 7.07s	remaining: 15.6s
# 312:	learn: 0.6635190	total: 7.09s	remaining: 15.6s
# 313:	learn: 0.6634065	total: 7.12s	remaining: 15.5s
# 314:	learn: 0.6633265	total: 7.14s	remaining: 15.5s
# 315:	learn: 0.6632424	total: 7.16s	remaining: 15.5s
# 316:	learn: 0.6631480	total: 7.18s	remaining: 15.5s
# 317:	learn: 0.6630461	total: 7.2s	remaining: 15.4s
# 318:	learn: 0.6629495	total: 7.22s	remaining: 15.4s
# 319:	learn: 0.6628524	total: 7.24s	remaining: 15.4s
# 320:	learn: 0.6627581	total: 7.26s	remaining: 15.4s
# 321:	learn: 0.6626471	total: 7.29s	remaining: 15.3s
# 322:	learn: 0.6625493	total: 7.31s	remaining: 15.3s
# 323:	learn: 0.6624497	total: 7.33s	remaining: 15.3s
# 324:	learn: 0.6623217	total: 7.36s	remaining: 15.3s
# 325:	learn: 0.6622155	total: 7.38s	remaining: 15.3s
# 326:	learn: 0.6621231	total: 7.4s	remaining: 15.2s
# 327:	learn: 0.6620283	total: 7.42s	remaining: 15.2s
# 328:	learn: 0.6619269	total: 7.45s	remaining: 15.2s
# 329:	learn: 0.6618170	total: 7.47s	remaining: 15.2s
# 330:	learn: 0.6617028	total: 7.49s	remaining: 15.1s
# 331:	learn: 0.6616149	total: 7.51s	remaining: 15.1s
# 332:	learn: 0.6615284	total: 7.53s	remaining: 15.1s
# 333:	learn: 0.6614319	total: 7.55s	remaining: 15.1s
# 334:	learn: 0.6613224	total: 7.58s	remaining: 15s
# 335:	learn: 0.6612205	total: 7.6s	remaining: 15s
# 336:	learn: 0.6611397	total: 7.62s	remaining: 15s
# 337:	learn: 0.6610359	total: 7.64s	remaining: 15s
# 338:	learn: 0.6609393	total: 7.67s	remaining: 15s
# 339:	learn: 0.6608183	total: 7.69s	remaining: 14.9s
# 340:	learn: 0.6607308	total: 7.71s	remaining: 14.9s
# 341:	learn: 0.6606171	total: 7.73s	remaining: 14.9s
# 342:	learn: 0.6605194	total: 7.75s	remaining: 14.9s
# 343:	learn: 0.6604148	total: 7.77s	remaining: 14.8s
# 344:	learn: 0.6603130	total: 7.79s	remaining: 14.8s
# 345:	learn: 0.6602197	total: 7.82s	remaining: 14.8s
# 346:	learn: 0.6601255	total: 7.84s	remaining: 14.8s
# 347:	learn: 0.6600202	total: 7.86s	remaining: 14.7s
# 348:	learn: 0.6599316	total: 7.88s	remaining: 14.7s
# 349:	learn: 0.6598463	total: 7.91s	remaining: 14.7s
# 350:	learn: 0.6597487	total: 7.93s	remaining: 14.7s
# 351:	learn: 0.6596434	total: 7.95s	remaining: 14.6s
# 352:	learn: 0.6595545	total: 7.97s	remaining: 14.6s
# 353:	learn: 0.6594594	total: 8s	remaining: 14.6s
# 354:	learn: 0.6594019	total: 8.02s	remaining: 14.6s
# 355:	learn: 0.6593142	total: 8.04s	remaining: 14.5s
# 356:	learn: 0.6592136	total: 8.06s	remaining: 14.5s
# 357:	learn: 0.6590908	total: 8.08s	remaining: 14.5s
# 358:	learn: 0.6589799	total: 8.1s	remaining: 14.5s
# 359:	learn: 0.6588966	total: 8.13s	remaining: 14.4s
# 360:	learn: 0.6588128	total: 8.15s	remaining: 14.4s
# 361:	learn: 0.6587243	total: 8.17s	remaining: 14.4s
# 362:	learn: 0.6586243	total: 8.19s	remaining: 14.4s
# 363:	learn: 0.6585237	total: 8.21s	remaining: 14.3s
# 364:	learn: 0.6584061	total: 8.23s	remaining: 14.3s
# 365:	learn: 0.6583224	total: 8.25s	remaining: 14.3s
# 366:	learn: 0.6582243	total: 8.28s	remaining: 14.3s
# 367:	learn: 0.6581365	total: 8.3s	remaining: 14.2s
# 368:	learn: 0.6580149	total: 8.32s	remaining: 14.2s
# 369:	learn: 0.6579026	total: 8.34s	remaining: 14.2s
# 370:	learn: 0.6578183	total: 8.37s	remaining: 14.2s
# 371:	learn: 0.6577344	total: 8.39s	remaining: 14.2s
# 372:	learn: 0.6576411	total: 8.41s	remaining: 14.1s
# 373:	learn: 0.6575246	total: 8.43s	remaining: 14.1s
# 374:	learn: 0.6574370	total: 8.45s	remaining: 14.1s
# 375:	learn: 0.6573083	total: 8.48s	remaining: 14.1s
# 376:	learn: 0.6571974	total: 8.5s	remaining: 14s
# 377:	learn: 0.6570925	total: 8.52s	remaining: 14s
# 378:	learn: 0.6570044	total: 8.54s	remaining: 14s
# 379:	learn: 0.6569091	total: 8.56s	remaining: 14s
# 380:	learn: 0.6568229	total: 8.58s	remaining: 13.9s
# 381:	learn: 0.6567321	total: 8.6s	remaining: 13.9s
# 382:	learn: 0.6566238	total: 8.64s	remaining: 13.9s
# 383:	learn: 0.6565220	total: 8.67s	remaining: 13.9s
# 384:	learn: 0.6564258	total: 8.7s	remaining: 13.9s
# 385:	learn: 0.6563476	total: 8.74s	remaining: 13.9s
# 386:	learn: 0.6562564	total: 8.78s	remaining: 13.9s
# 387:	learn: 0.6561768	total: 8.82s	remaining: 13.9s
# 388:	learn: 0.6560654	total: 8.86s	remaining: 13.9s
# 389:	learn: 0.6559888	total: 8.9s	remaining: 13.9s
# 390:	learn: 0.6558691	total: 8.93s	remaining: 13.9s
# 391:	learn: 0.6557623	total: 8.96s	remaining: 13.9s
# 392:	learn: 0.6556651	total: 9s	remaining: 13.9s
# 393:	learn: 0.6555695	total: 9.03s	remaining: 13.9s
# 394:	learn: 0.6554942	total: 9.06s	remaining: 13.9s
# 395:	learn: 0.6553843	total: 9.09s	remaining: 13.9s
# 396:	learn: 0.6552904	total: 9.12s	remaining: 13.9s
# 397:	learn: 0.6551863	total: 9.15s	remaining: 13.8s
# 398:	learn: 0.6550946	total: 9.2s	remaining: 13.8s
# 399:	learn: 0.6550029	total: 9.23s	remaining: 13.8s
# 400:	learn: 0.6548967	total: 9.28s	remaining: 13.9s
# 401:	learn: 0.6548064	total: 9.31s	remaining: 13.8s
# 402:	learn: 0.6546998	total: 9.34s	remaining: 13.8s
# 403:	learn: 0.6546140	total: 9.38s	remaining: 13.8s
# 404:	learn: 0.6545081	total: 9.41s	remaining: 13.8s
# 405:	learn: 0.6544161	total: 9.44s	remaining: 13.8s
# 406:	learn: 0.6543396	total: 9.46s	remaining: 13.8s
# 407:	learn: 0.6542318	total: 9.5s	remaining: 13.8s
# 408:	learn: 0.6541205	total: 9.53s	remaining: 13.8s
# 409:	learn: 0.6540342	total: 9.55s	remaining: 13.7s
# 410:	learn: 0.6539218	total: 9.59s	remaining: 13.7s
# 411:	learn: 0.6538318	total: 9.62s	remaining: 13.7s
# 412:	learn: 0.6537246	total: 9.65s	remaining: 13.7s
# 413:	learn: 0.6536212	total: 9.68s	remaining: 13.7s
# 414:	learn: 0.6535262	total: 9.7s	remaining: 13.7s
# 415:	learn: 0.6534172	total: 9.73s	remaining: 13.7s
# 416:	learn: 0.6533239	total: 9.76s	remaining: 13.6s
# 417:	learn: 0.6532327	total: 9.79s	remaining: 13.6s
# 418:	learn: 0.6531369	total: 9.82s	remaining: 13.6s
# 419:	learn: 0.6530430	total: 9.85s	remaining: 13.6s
# 420:	learn: 0.6529448	total: 9.88s	remaining: 13.6s
# 421:	learn: 0.6528565	total: 9.9s	remaining: 13.6s
# 422:	learn: 0.6527716	total: 9.94s	remaining: 13.6s
# 423:	learn: 0.6526643	total: 9.96s	remaining: 13.5s
# 424:	learn: 0.6525707	total: 9.99s	remaining: 13.5s
# 425:	learn: 0.6524808	total: 10s	remaining: 13.5s
# 426:	learn: 0.6523752	total: 10.1s	remaining: 13.5s
# 427:	learn: 0.6522792	total: 10.1s	remaining: 13.5s
# 428:	learn: 0.6521864	total: 10.1s	remaining: 13.5s
# 429:	learn: 0.6521083	total: 10.2s	remaining: 13.5s
# 430:	learn: 0.6519990	total: 10.2s	remaining: 13.4s
# 431:	learn: 0.6518924	total: 10.2s	remaining: 13.4s
# 432:	learn: 0.6517892	total: 10.2s	remaining: 13.4s
# 433:	learn: 0.6517103	total: 10.3s	remaining: 13.4s
# 434:	learn: 0.6516315	total: 10.3s	remaining: 13.4s
# 435:	learn: 0.6515184	total: 10.3s	remaining: 13.3s
# 436:	learn: 0.6514242	total: 10.3s	remaining: 13.3s
# 437:	learn: 0.6513107	total: 10.4s	remaining: 13.3s
# 438:	learn: 0.6512116	total: 10.4s	remaining: 13.3s
# 439:	learn: 0.6511180	total: 10.4s	remaining: 13.2s
# 440:	learn: 0.6510122	total: 10.4s	remaining: 13.2s
# 441:	learn: 0.6509041	total: 10.5s	remaining: 13.2s
# 442:	learn: 0.6508112	total: 10.5s	remaining: 13.2s
# 443:	learn: 0.6507210	total: 10.5s	remaining: 13.1s
# 444:	learn: 0.6506243	total: 10.5s	remaining: 13.1s
# 445:	learn: 0.6505538	total: 10.5s	remaining: 13.1s
# 446:	learn: 0.6504505	total: 10.6s	remaining: 13.1s
# 447:	learn: 0.6503470	total: 10.6s	remaining: 13s
# 448:	learn: 0.6502710	total: 10.6s	remaining: 13s
# 449:	learn: 0.6501764	total: 10.6s	remaining: 13s
# 450:	learn: 0.6500915	total: 10.6s	remaining: 13s
# 451:	learn: 0.6500005	total: 10.7s	remaining: 12.9s
# 452:	learn: 0.6498980	total: 10.7s	remaining: 12.9s
# 453:	learn: 0.6498016	total: 10.7s	remaining: 12.9s
# 454:	learn: 0.6496999	total: 10.7s	remaining: 12.8s
# 455:	learn: 0.6496177	total: 10.7s	remaining: 12.8s
# 456:	learn: 0.6494842	total: 10.8s	remaining: 12.8s
# 457:	learn: 0.6493991	total: 10.8s	remaining: 12.8s
# 458:	learn: 0.6493087	total: 10.8s	remaining: 12.7s
# 459:	learn: 0.6492272	total: 10.8s	remaining: 12.7s
# 460:	learn: 0.6491409	total: 10.9s	remaining: 12.7s
# 461:	learn: 0.6490582	total: 10.9s	remaining: 12.7s
# 462:	learn: 0.6489843	total: 10.9s	remaining: 12.6s
# 463:	learn: 0.6489018	total: 10.9s	remaining: 12.6s
# 464:	learn: 0.6488050	total: 10.9s	remaining: 12.6s
# 465:	learn: 0.6487039	total: 11s	remaining: 12.6s
# 466:	learn: 0.6486124	total: 11s	remaining: 12.5s
# 467:	learn: 0.6485407	total: 11s	remaining: 12.5s
# 468:	learn: 0.6484304	total: 11s	remaining: 12.5s
# 469:	learn: 0.6483510	total: 11.1s	remaining: 12.5s
# 470:	learn: 0.6482652	total: 11.1s	remaining: 12.4s
# 471:	learn: 0.6481407	total: 11.1s	remaining: 12.4s
# 472:	learn: 0.6480543	total: 11.1s	remaining: 12.4s
# 473:	learn: 0.6479726	total: 11.2s	remaining: 12.4s
# 474:	learn: 0.6478945	total: 11.2s	remaining: 12.3s
# 475:	learn: 0.6478016	total: 11.2s	remaining: 12.3s
# 476:	learn: 0.6477108	total: 11.2s	remaining: 12.3s
# 477:	learn: 0.6476162	total: 11.2s	remaining: 12.3s
# 478:	learn: 0.6475309	total: 11.3s	remaining: 12.2s
# 479:	learn: 0.6474175	total: 11.3s	remaining: 12.2s
# 480:	learn: 0.6473092	total: 11.3s	remaining: 12.2s
# 481:	learn: 0.6472013	total: 11.3s	remaining: 12.2s
# 482:	learn: 0.6471175	total: 11.4s	remaining: 12.2s
# 483:	learn: 0.6470315	total: 11.4s	remaining: 12.1s
# 484:	learn: 0.6469351	total: 11.4s	remaining: 12.1s
# 485:	learn: 0.6468177	total: 11.4s	remaining: 12.1s
# 486:	learn: 0.6467215	total: 11.4s	remaining: 12.1s
# 487:	learn: 0.6466212	total: 11.5s	remaining: 12s
# 488:	learn: 0.6465237	total: 11.5s	remaining: 12s
# 489:	learn: 0.6464059	total: 11.5s	remaining: 12s
# 490:	learn: 0.6463080	total: 11.5s	remaining: 12s
# 491:	learn: 0.6461904	total: 11.6s	remaining: 11.9s
# 492:	learn: 0.6461023	total: 11.6s	remaining: 11.9s
# 493:	learn: 0.6460064	total: 11.6s	remaining: 11.9s
# 494:	learn: 0.6459031	total: 11.6s	remaining: 11.9s
# 495:	learn: 0.6458000	total: 11.6s	remaining: 11.8s
# 496:	learn: 0.6457007	total: 11.7s	remaining: 11.8s
# 497:	learn: 0.6456220	total: 11.7s	remaining: 11.8s
# 498:	learn: 0.6455180	total: 11.7s	remaining: 11.8s
# 499:	learn: 0.6454174	total: 11.7s	remaining: 11.7s
# 500:	learn: 0.6453294	total: 11.8s	remaining: 11.7s
# 501:	learn: 0.6452418	total: 11.8s	remaining: 11.7s
# 502:	learn: 0.6451492	total: 11.8s	remaining: 11.7s
# 503:	learn: 0.6450744	total: 11.8s	remaining: 11.6s
# 504:	learn: 0.6449959	total: 11.8s	remaining: 11.6s
# 505:	learn: 0.6448994	total: 11.9s	remaining: 11.6s
# 506:	learn: 0.6448096	total: 11.9s	remaining: 11.6s
# 507:	learn: 0.6447203	total: 11.9s	remaining: 11.5s
# 508:	learn: 0.6446230	total: 11.9s	remaining: 11.5s
# 509:	learn: 0.6445346	total: 12s	remaining: 11.5s
# 510:	learn: 0.6444418	total: 12s	remaining: 11.5s
# 511:	learn: 0.6443417	total: 12s	remaining: 11.4s
# 512:	learn: 0.6442432	total: 12s	remaining: 11.4s
# 513:	learn: 0.6441669	total: 12.1s	remaining: 11.4s
# 514:	learn: 0.6440718	total: 12.1s	remaining: 11.4s
# 515:	learn: 0.6439781	total: 12.1s	remaining: 11.4s
# 516:	learn: 0.6438906	total: 12.2s	remaining: 11.4s
# 517:	learn: 0.6437924	total: 12.2s	remaining: 11.3s
# 518:	learn: 0.6436781	total: 12.2s	remaining: 11.3s
# 519:	learn: 0.6435974	total: 12.2s	remaining: 11.3s
# 520:	learn: 0.6435102	total: 12.2s	remaining: 11.3s
# 521:	learn: 0.6434101	total: 12.3s	remaining: 11.2s
# 522:	learn: 0.6433148	total: 12.3s	remaining: 11.2s
# 523:	learn: 0.6432121	total: 12.3s	remaining: 11.2s
# 524:	learn: 0.6431238	total: 12.3s	remaining: 11.2s
# 525:	learn: 0.6430363	total: 12.4s	remaining: 11.1s
# 526:	learn: 0.6429525	total: 12.4s	remaining: 11.1s
# 527:	learn: 0.6428559	total: 12.4s	remaining: 11.1s
# 528:	learn: 0.6427549	total: 12.4s	remaining: 11.1s
# 529:	learn: 0.6426715	total: 12.4s	remaining: 11s
# 530:	learn: 0.6425698	total: 12.5s	remaining: 11s
# 531:	learn: 0.6424785	total: 12.5s	remaining: 11s
# 532:	learn: 0.6423874	total: 12.5s	remaining: 11s
# 533:	learn: 0.6422881	total: 12.5s	remaining: 10.9s
# 534:	learn: 0.6422215	total: 12.6s	remaining: 10.9s
# 535:	learn: 0.6421334	total: 12.6s	remaining: 10.9s
# 536:	learn: 0.6420277	total: 12.6s	remaining: 10.9s
# 537:	learn: 0.6419426	total: 12.6s	remaining: 10.8s
# 538:	learn: 0.6418611	total: 12.6s	remaining: 10.8s
# 539:	learn: 0.6417732	total: 12.7s	remaining: 10.8s
# 540:	learn: 0.6416901	total: 12.7s	remaining: 10.8s
# 541:	learn: 0.6415962	total: 12.7s	remaining: 10.7s
# 542:	learn: 0.6414961	total: 12.7s	remaining: 10.7s
# 543:	learn: 0.6414179	total: 12.7s	remaining: 10.7s
# 544:	learn: 0.6413196	total: 12.8s	remaining: 10.7s
# 545:	learn: 0.6412229	total: 12.8s	remaining: 10.6s
# 546:	learn: 0.6411268	total: 12.8s	remaining: 10.6s
# 547:	learn: 0.6410152	total: 12.8s	remaining: 10.6s
# 548:	learn: 0.6409094	total: 12.9s	remaining: 10.6s
# 549:	learn: 0.6408018	total: 12.9s	remaining: 10.5s
# 550:	learn: 0.6407190	total: 12.9s	remaining: 10.5s
# 551:	learn: 0.6406163	total: 12.9s	remaining: 10.5s
# 552:	learn: 0.6405281	total: 12.9s	remaining: 10.5s
# 553:	learn: 0.6404332	total: 13s	remaining: 10.4s
# 554:	learn: 0.6403423	total: 13s	remaining: 10.4s
# 555:	learn: 0.6402489	total: 13s	remaining: 10.4s
# 556:	learn: 0.6401518	total: 13s	remaining: 10.4s
# 557:	learn: 0.6400622	total: 13.1s	remaining: 10.3s
# 558:	learn: 0.6399720	total: 13.1s	remaining: 10.3s
# 559:	learn: 0.6398860	total: 13.1s	remaining: 10.3s
# 560:	learn: 0.6397992	total: 13.1s	remaining: 10.3s
# 561:	learn: 0.6396938	total: 13.1s	remaining: 10.2s
# 562:	learn: 0.6395958	total: 13.2s	remaining: 10.2s
# 563:	learn: 0.6394999	total: 13.2s	remaining: 10.2s
# 564:	learn: 0.6393858	total: 13.2s	remaining: 10.2s
# 565:	learn: 0.6392863	total: 13.2s	remaining: 10.2s
# 566:	learn: 0.6391775	total: 13.3s	remaining: 10.1s
# 567:	learn: 0.6390711	total: 13.3s	remaining: 10.1s
# 568:	learn: 0.6389636	total: 13.3s	remaining: 10.1s
# 569:	learn: 0.6388805	total: 13.3s	remaining: 10.1s
# 570:	learn: 0.6387861	total: 13.4s	remaining: 10s
# 571:	learn: 0.6386911	total: 13.4s	remaining: 10s
# 572:	learn: 0.6385997	total: 13.4s	remaining: 9.98s
# 573:	learn: 0.6384957	total: 13.4s	remaining: 9.96s
# 574:	learn: 0.6384060	total: 13.4s	remaining: 9.94s
# 575:	learn: 0.6383447	total: 13.5s	remaining: 9.91s
# 576:	learn: 0.6382500	total: 13.5s	remaining: 9.89s
# 577:	learn: 0.6381745	total: 13.5s	remaining: 9.86s
# 578:	learn: 0.6380749	total: 13.5s	remaining: 9.84s
# 579:	learn: 0.6379807	total: 13.6s	remaining: 9.81s
# 580:	learn: 0.6378773	total: 13.6s	remaining: 9.79s
# 581:	learn: 0.6377818	total: 13.6s	remaining: 9.77s
# 582:	learn: 0.6377026	total: 13.6s	remaining: 9.74s
# 583:	learn: 0.6376194	total: 13.6s	remaining: 9.72s
# 584:	learn: 0.6375462	total: 13.7s	remaining: 9.7s
# 585:	learn: 0.6374374	total: 13.7s	remaining: 9.67s
# 586:	learn: 0.6373501	total: 13.7s	remaining: 9.64s
# 587:	learn: 0.6372792	total: 13.7s	remaining: 9.62s
# 588:	learn: 0.6371910	total: 13.8s	remaining: 9.59s
# 589:	learn: 0.6371122	total: 13.8s	remaining: 9.57s
# 590:	learn: 0.6370126	total: 13.8s	remaining: 9.54s
# 591:	learn: 0.6369319	total: 13.8s	remaining: 9.52s
# 592:	learn: 0.6368271	total: 13.8s	remaining: 9.5s
# 593:	learn: 0.6367542	total: 13.9s	remaining: 9.47s
# 594:	learn: 0.6366676	total: 13.9s	remaining: 9.45s
# 595:	learn: 0.6365824	total: 13.9s	remaining: 9.42s
# 596:	learn: 0.6364730	total: 13.9s	remaining: 9.4s
# 597:	learn: 0.6363758	total: 13.9s	remaining: 9.38s
# 598:	learn: 0.6362966	total: 14s	remaining: 9.36s
# 599:	learn: 0.6362179	total: 14s	remaining: 9.33s
# 600:	learn: 0.6361265	total: 14s	remaining: 9.3s
# 601:	learn: 0.6360574	total: 14s	remaining: 9.28s
# 602:	learn: 0.6359649	total: 14.1s	remaining: 9.26s
# 603:	learn: 0.6358776	total: 14.1s	remaining: 9.23s
# 604:	learn: 0.6357859	total: 14.1s	remaining: 9.21s
# 605:	learn: 0.6357013	total: 14.1s	remaining: 9.18s
# 606:	learn: 0.6356082	total: 14.1s	remaining: 9.16s
# 607:	learn: 0.6355242	total: 14.2s	remaining: 9.13s
# 608:	learn: 0.6354415	total: 14.2s	remaining: 9.11s
# 609:	learn: 0.6353471	total: 14.2s	remaining: 9.08s
# 610:	learn: 0.6352368	total: 14.2s	remaining: 9.06s
# 611:	learn: 0.6351447	total: 14.3s	remaining: 9.04s
# 612:	learn: 0.6350518	total: 14.3s	remaining: 9.01s
# 613:	learn: 0.6349557	total: 14.3s	remaining: 8.99s
# 614:	learn: 0.6348724	total: 14.3s	remaining: 8.96s
# 615:	learn: 0.6347727	total: 14.3s	remaining: 8.94s
# 616:	learn: 0.6346953	total: 14.4s	remaining: 8.92s
# 617:	learn: 0.6346084	total: 14.4s	remaining: 8.89s
# 618:	learn: 0.6345384	total: 14.4s	remaining: 8.87s
# 619:	learn: 0.6344424	total: 14.4s	remaining: 8.84s
# 620:	learn: 0.6343578	total: 14.4s	remaining: 8.82s
# 621:	learn: 0.6342605	total: 14.5s	remaining: 8.79s
# 622:	learn: 0.6341460	total: 14.5s	remaining: 8.77s
# 623:	learn: 0.6340439	total: 14.5s	remaining: 8.75s
# 624:	learn: 0.6339499	total: 14.5s	remaining: 8.73s
# 625:	learn: 0.6338497	total: 14.6s	remaining: 8.7s
# 626:	learn: 0.6337686	total: 14.6s	remaining: 8.68s
# 627:	learn: 0.6336857	total: 14.6s	remaining: 8.65s
# 628:	learn: 0.6335827	total: 14.6s	remaining: 8.63s
# 629:	learn: 0.6334869	total: 14.7s	remaining: 8.61s
# 630:	learn: 0.6333974	total: 14.7s	remaining: 8.58s
# 631:	learn: 0.6332986	total: 14.7s	remaining: 8.56s
# 632:	learn: 0.6331972	total: 14.7s	remaining: 8.54s
# 633:	learn: 0.6331149	total: 14.7s	remaining: 8.51s
# 634:	learn: 0.6330317	total: 14.8s	remaining: 8.49s
# 635:	learn: 0.6329207	total: 14.8s	remaining: 8.46s
# 636:	learn: 0.6328244	total: 14.8s	remaining: 8.44s
# 637:	learn: 0.6327476	total: 14.8s	remaining: 8.42s
# 638:	learn: 0.6326632	total: 14.9s	remaining: 8.39s
# 639:	learn: 0.6325716	total: 14.9s	remaining: 8.37s
# 640:	learn: 0.6325080	total: 14.9s	remaining: 8.35s
# 641:	learn: 0.6324193	total: 14.9s	remaining: 8.32s
# 642:	learn: 0.6323429	total: 14.9s	remaining: 8.3s
# 643:	learn: 0.6322679	total: 15s	remaining: 8.27s
# 644:	learn: 0.6321614	total: 15s	remaining: 8.25s
# 645:	learn: 0.6320819	total: 15s	remaining: 8.22s
# 646:	learn: 0.6319998	total: 15s	remaining: 8.2s
# 647:	learn: 0.6318871	total: 15.1s	remaining: 8.18s
# 648:	learn: 0.6317992	total: 15.1s	remaining: 8.15s
# 649:	learn: 0.6317070	total: 15.1s	remaining: 8.13s
# 650:	learn: 0.6316166	total: 15.1s	remaining: 8.11s
# 651:	learn: 0.6315426	total: 15.1s	remaining: 8.08s
# 652:	learn: 0.6314517	total: 15.2s	remaining: 8.06s
# 653:	learn: 0.6313536	total: 15.2s	remaining: 8.03s
# 654:	learn: 0.6312517	total: 15.2s	remaining: 8.01s
# 655:	learn: 0.6311519	total: 15.2s	remaining: 7.99s
# 656:	learn: 0.6310738	total: 15.3s	remaining: 7.96s
# 657:	learn: 0.6309779	total: 15.3s	remaining: 7.94s
# 658:	learn: 0.6308777	total: 15.3s	remaining: 7.92s
# 659:	learn: 0.6307967	total: 15.3s	remaining: 7.89s
# 660:	learn: 0.6307048	total: 15.3s	remaining: 7.87s
# 661:	learn: 0.6306195	total: 15.4s	remaining: 7.85s
# 662:	learn: 0.6305285	total: 15.4s	remaining: 7.82s
# 663:	learn: 0.6304412	total: 15.4s	remaining: 7.8s
# 664:	learn: 0.6303567	total: 15.4s	remaining: 7.77s
# 665:	learn: 0.6302710	total: 15.5s	remaining: 7.75s
# 666:	learn: 0.6301793	total: 15.5s	remaining: 7.73s
# 667:	learn: 0.6301017	total: 15.5s	remaining: 7.71s
# 668:	learn: 0.6300298	total: 15.5s	remaining: 7.68s
# 669:	learn: 0.6299353	total: 15.6s	remaining: 7.66s
# 670:	learn: 0.6298623	total: 15.6s	remaining: 7.63s
# 671:	learn: 0.6297661	total: 15.6s	remaining: 7.61s
# 672:	learn: 0.6296776	total: 15.6s	remaining: 7.59s
# 673:	learn: 0.6295994	total: 15.6s	remaining: 7.56s
# 674:	learn: 0.6295347	total: 15.7s	remaining: 7.54s
# 675:	learn: 0.6294662	total: 15.7s	remaining: 7.51s
# 676:	learn: 0.6293894	total: 15.7s	remaining: 7.49s
# 677:	learn: 0.6292923	total: 15.7s	remaining: 7.46s
# 678:	learn: 0.6292198	total: 15.7s	remaining: 7.44s
# 679:	learn: 0.6291439	total: 15.8s	remaining: 7.42s
# 680:	learn: 0.6290533	total: 15.8s	remaining: 7.39s
# 681:	learn: 0.6289773	total: 15.8s	remaining: 7.37s
# 682:	learn: 0.6288984	total: 15.8s	remaining: 7.34s
# 683:	learn: 0.6287816	total: 15.8s	remaining: 7.32s
# 684:	learn: 0.6286910	total: 15.9s	remaining: 7.29s
# 685:	learn: 0.6286065	total: 15.9s	remaining: 7.27s
# 686:	learn: 0.6285218	total: 15.9s	remaining: 7.25s
# 687:	learn: 0.6284104	total: 15.9s	remaining: 7.22s
# 688:	learn: 0.6283312	total: 16s	remaining: 7.2s
# 689:	learn: 0.6282514	total: 16s	remaining: 7.18s
# 690:	learn: 0.6281480	total: 16s	remaining: 7.15s
# 691:	learn: 0.6280796	total: 16s	remaining: 7.13s
# 692:	learn: 0.6279945	total: 16s	remaining: 7.11s
# 693:	learn: 0.6278855	total: 16.1s	remaining: 7.08s
# 694:	learn: 0.6278022	total: 16.1s	remaining: 7.06s
# 695:	learn: 0.6276845	total: 16.1s	remaining: 7.03s
# 696:	learn: 0.6276099	total: 16.1s	remaining: 7.01s
# 697:	learn: 0.6275159	total: 16.2s	remaining: 6.99s
# 698:	learn: 0.6273977	total: 16.2s	remaining: 6.96s
# 699:	learn: 0.6272963	total: 16.2s	remaining: 6.94s
# 700:	learn: 0.6272017	total: 16.2s	remaining: 6.92s
# 701:	learn: 0.6271123	total: 16.2s	remaining: 6.89s
# 702:	learn: 0.6270250	total: 16.3s	remaining: 6.87s
# 703:	learn: 0.6269452	total: 16.3s	remaining: 6.84s
# 704:	learn: 0.6268334	total: 16.3s	remaining: 6.82s
# 705:	learn: 0.6267522	total: 16.3s	remaining: 6.8s
# 706:	learn: 0.6266727	total: 16.3s	remaining: 6.78s
# 707:	learn: 0.6266061	total: 16.4s	remaining: 6.75s
# 708:	learn: 0.6265322	total: 16.4s	remaining: 6.73s
# 709:	learn: 0.6264414	total: 16.4s	remaining: 6.7s
# 710:	learn: 0.6263564	total: 16.4s	remaining: 6.68s
# 711:	learn: 0.6262682	total: 16.5s	remaining: 6.66s
# 712:	learn: 0.6261757	total: 16.5s	remaining: 6.63s
# 713:	learn: 0.6260948	total: 16.5s	remaining: 6.61s
# 714:	learn: 0.6260149	total: 16.5s	remaining: 6.58s
# 715:	learn: 0.6259421	total: 16.5s	remaining: 6.56s
# 716:	learn: 0.6258756	total: 16.6s	remaining: 6.54s
# 717:	learn: 0.6257868	total: 16.6s	remaining: 6.51s
# 718:	learn: 0.6256986	total: 16.6s	remaining: 6.49s
# 719:	learn: 0.6256180	total: 16.6s	remaining: 6.47s
# 720:	learn: 0.6255052	total: 16.7s	remaining: 6.45s
# 721:	learn: 0.6253987	total: 16.7s	remaining: 6.42s
# 722:	learn: 0.6252939	total: 16.7s	remaining: 6.4s
# 723:	learn: 0.6252037	total: 16.7s	remaining: 6.38s
# 724:	learn: 0.6251278	total: 16.7s	remaining: 6.35s
# 725:	learn: 0.6250541	total: 16.8s	remaining: 6.33s
# 726:	learn: 0.6249622	total: 16.8s	remaining: 6.31s
# 727:	learn: 0.6248862	total: 16.8s	remaining: 6.28s
# 728:	learn: 0.6247881	total: 16.8s	remaining: 6.26s
# 729:	learn: 0.6247075	total: 16.9s	remaining: 6.24s
# 730:	learn: 0.6246186	total: 16.9s	remaining: 6.21s
# 731:	learn: 0.6245253	total: 16.9s	remaining: 6.19s
# 732:	learn: 0.6244397	total: 16.9s	remaining: 6.17s
# 733:	learn: 0.6243480	total: 17s	remaining: 6.14s
# 734:	learn: 0.6242595	total: 17s	remaining: 6.12s
# 735:	learn: 0.6241952	total: 17s	remaining: 6.1s
# 736:	learn: 0.6241152	total: 17s	remaining: 6.07s
# 737:	learn: 0.6240213	total: 17s	remaining: 6.05s
# 738:	learn: 0.6239170	total: 17.1s	remaining: 6.03s
# 739:	learn: 0.6238223	total: 17.1s	remaining: 6s
# 740:	learn: 0.6237456	total: 17.1s	remaining: 5.98s
# 741:	learn: 0.6236406	total: 17.1s	remaining: 5.96s
# 742:	learn: 0.6235470	total: 17.2s	remaining: 5.93s
# 743:	learn: 0.6234785	total: 17.2s	remaining: 5.91s
# 744:	learn: 0.6233808	total: 17.2s	remaining: 5.88s
# 745:	learn: 0.6232750	total: 17.2s	remaining: 5.86s
# 746:	learn: 0.6231814	total: 17.2s	remaining: 5.84s
# 747:	learn: 0.6230980	total: 17.3s	remaining: 5.82s
# 748:	learn: 0.6230130	total: 17.3s	remaining: 5.79s
# 749:	learn: 0.6229238	total: 17.3s	remaining: 5.77s
# 750:	learn: 0.6228208	total: 17.3s	remaining: 5.75s
# 751:	learn: 0.6227352	total: 17.4s	remaining: 5.72s
# 752:	learn: 0.6226710	total: 17.4s	remaining: 5.7s
# 753:	learn: 0.6225725	total: 17.4s	remaining: 5.68s
# 754:	learn: 0.6224722	total: 17.4s	remaining: 5.66s
# 755:	learn: 0.6223947	total: 17.5s	remaining: 5.63s
# 756:	learn: 0.6223117	total: 17.5s	remaining: 5.61s
# 757:	learn: 0.6222330	total: 17.5s	remaining: 5.59s
# 758:	learn: 0.6221213	total: 17.5s	remaining: 5.57s
# 759:	learn: 0.6220406	total: 17.5s	remaining: 5.54s
# 760:	learn: 0.6219533	total: 17.6s	remaining: 5.52s
# 761:	learn: 0.6218403	total: 17.6s	remaining: 5.49s
# 762:	learn: 0.6217694	total: 17.6s	remaining: 5.47s
# 763:	learn: 0.6216855	total: 17.6s	remaining: 5.45s
# 764:	learn: 0.6216139	total: 17.7s	remaining: 5.42s
# 765:	learn: 0.6215130	total: 17.7s	remaining: 5.4s
# 766:	learn: 0.6214516	total: 17.7s	remaining: 5.38s
# 767:	learn: 0.6213901	total: 17.7s	remaining: 5.35s
# 768:	learn: 0.6212994	total: 17.8s	remaining: 5.33s
# 769:	learn: 0.6212196	total: 17.8s	remaining: 5.31s
# 770:	learn: 0.6211305	total: 17.8s	remaining: 5.28s
# 771:	learn: 0.6210385	total: 17.8s	remaining: 5.26s
# 772:	learn: 0.6209462	total: 17.8s	remaining: 5.24s
# 773:	learn: 0.6208690	total: 17.9s	remaining: 5.21s
# 774:	learn: 0.6207984	total: 17.9s	remaining: 5.19s
# 775:	learn: 0.6206988	total: 17.9s	remaining: 5.17s
# 776:	learn: 0.6206038	total: 17.9s	remaining: 5.14s
# 777:	learn: 0.6205101	total: 17.9s	remaining: 5.12s
# 778:	learn: 0.6204234	total: 18s	remaining: 5.1s
# 779:	learn: 0.6203470	total: 18s	remaining: 5.07s
# 780:	learn: 0.6202617	total: 18s	remaining: 5.05s
# 781:	learn: 0.6201854	total: 18s	remaining: 5.03s
# 782:	learn: 0.6200940	total: 18.1s	remaining: 5s
# 783:	learn: 0.6200127	total: 18.1s	remaining: 4.98s
# 784:	learn: 0.6199253	total: 18.1s	remaining: 4.96s
# 785:	learn: 0.6198370	total: 18.1s	remaining: 4.93s
# 786:	learn: 0.6197497	total: 18.1s	remaining: 4.91s
# 787:	learn: 0.6196719	total: 18.2s	remaining: 4.89s
# 788:	learn: 0.6195804	total: 18.2s	remaining: 4.86s
# 789:	learn: 0.6195051	total: 18.2s	remaining: 4.84s
# 790:	learn: 0.6194237	total: 18.2s	remaining: 4.82s
# 791:	learn: 0.6193252	total: 18.3s	remaining: 4.79s
# 792:	learn: 0.6192420	total: 18.3s	remaining: 4.77s
# 793:	learn: 0.6191601	total: 18.3s	remaining: 4.75s
# 794:	learn: 0.6190672	total: 18.3s	remaining: 4.73s
# 795:	learn: 0.6189778	total: 18.4s	remaining: 4.7s
# 796:	learn: 0.6188801	total: 18.4s	remaining: 4.68s
# 797:	learn: 0.6187793	total: 18.4s	remaining: 4.66s
# 798:	learn: 0.6187013	total: 18.4s	remaining: 4.63s
# 799:	learn: 0.6186116	total: 18.4s	remaining: 4.61s
# 800:	learn: 0.6185297	total: 18.5s	remaining: 4.59s
# 801:	learn: 0.6184435	total: 18.5s	remaining: 4.56s
# 802:	learn: 0.6183596	total: 18.5s	remaining: 4.54s
# 803:	learn: 0.6182626	total: 18.5s	remaining: 4.52s
# 804:	learn: 0.6181743	total: 18.6s	remaining: 4.49s
# 805:	learn: 0.6180731	total: 18.6s	remaining: 4.47s
# 806:	learn: 0.6179992	total: 18.6s	remaining: 4.45s
# 807:	learn: 0.6178990	total: 18.6s	remaining: 4.42s
# 808:	learn: 0.6178157	total: 18.6s	remaining: 4.4s
# 809:	learn: 0.6177433	total: 18.7s	remaining: 4.38s
# 810:	learn: 0.6176715	total: 18.7s	remaining: 4.35s
# 811:	learn: 0.6175915	total: 18.7s	remaining: 4.33s
# 812:	learn: 0.6174964	total: 18.7s	remaining: 4.31s
# 813:	learn: 0.6174119	total: 18.7s	remaining: 4.28s
# 814:	learn: 0.6172977	total: 18.8s	remaining: 4.26s
# 815:	learn: 0.6172185	total: 18.8s	remaining: 4.24s
# 816:	learn: 0.6171335	total: 18.8s	remaining: 4.21s
# 817:	learn: 0.6170697	total: 18.8s	remaining: 4.19s
# 818:	learn: 0.6169623	total: 18.9s	remaining: 4.17s
# 819:	learn: 0.6168676	total: 18.9s	remaining: 4.14s
# 820:	learn: 0.6167906	total: 18.9s	remaining: 4.12s
# 821:	learn: 0.6167046	total: 18.9s	remaining: 4.1s
# 822:	learn: 0.6166198	total: 18.9s	remaining: 4.07s
# 823:	learn: 0.6165405	total: 19s	remaining: 4.05s
# 824:	learn: 0.6164656	total: 19s	remaining: 4.03s
# 825:	learn: 0.6163781	total: 19s	remaining: 4s
# 826:	learn: 0.6162964	total: 19s	remaining: 3.98s
# 827:	learn: 0.6161857	total: 19s	remaining: 3.96s
# 828:	learn: 0.6160914	total: 19.1s	remaining: 3.93s
# 829:	learn: 0.6160066	total: 19.1s	remaining: 3.91s
# 830:	learn: 0.6159097	total: 19.1s	remaining: 3.89s
# 831:	learn: 0.6158178	total: 19.1s	remaining: 3.86s
# 832:	learn: 0.6157174	total: 19.2s	remaining: 3.84s
# 833:	learn: 0.6156388	total: 19.2s	remaining: 3.82s
# 834:	learn: 0.6155320	total: 19.2s	remaining: 3.79s
# 835:	learn: 0.6154432	total: 19.2s	remaining: 3.77s
# 836:	learn: 0.6153467	total: 19.2s	remaining: 3.75s
# 837:	learn: 0.6152797	total: 19.3s	remaining: 3.72s
# 838:	learn: 0.6152117	total: 19.3s	remaining: 3.7s
# 839:	learn: 0.6151096	total: 19.3s	remaining: 3.68s
# 840:	learn: 0.6150251	total: 19.3s	remaining: 3.65s
# 841:	learn: 0.6149341	total: 19.4s	remaining: 3.63s
# 842:	learn: 0.6148537	total: 19.4s	remaining: 3.61s
# 843:	learn: 0.6147803	total: 19.4s	remaining: 3.58s
# 844:	learn: 0.6147174	total: 19.4s	remaining: 3.56s
# 845:	learn: 0.6146267	total: 19.4s	remaining: 3.54s
# 846:	learn: 0.6145359	total: 19.5s	remaining: 3.52s
# 847:	learn: 0.6144670	total: 19.5s	remaining: 3.49s
# 848:	learn: 0.6143755	total: 19.5s	remaining: 3.47s
# 849:	learn: 0.6142899	total: 19.5s	remaining: 3.44s
# 850:	learn: 0.6141926	total: 19.6s	remaining: 3.42s
# 851:	learn: 0.6141010	total: 19.6s	remaining: 3.4s
# 852:	learn: 0.6140027	total: 19.6s	remaining: 3.38s
# 853:	learn: 0.6139184	total: 19.6s	remaining: 3.35s
# 854:	learn: 0.6138161	total: 19.6s	remaining: 3.33s
# 855:	learn: 0.6137072	total: 19.7s	remaining: 3.31s
# 856:	learn: 0.6136276	total: 19.7s	remaining: 3.28s
# 857:	learn: 0.6135338	total: 19.7s	remaining: 3.26s
# 858:	learn: 0.6134385	total: 19.7s	remaining: 3.24s
# 859:	learn: 0.6133458	total: 19.8s	remaining: 3.21s
# 860:	learn: 0.6132619	total: 19.8s	remaining: 3.19s
# 861:	learn: 0.6131993	total: 19.8s	remaining: 3.17s
# 862:	learn: 0.6131069	total: 19.8s	remaining: 3.15s
# 863:	learn: 0.6130062	total: 19.8s	remaining: 3.12s
# 864:	learn: 0.6129177	total: 19.9s	remaining: 3.1s
# 865:	learn: 0.6128392	total: 19.9s	remaining: 3.08s
# 866:	learn: 0.6127636	total: 19.9s	remaining: 3.05s
# 867:	learn: 0.6126802	total: 19.9s	remaining: 3.03s
# 868:	learn: 0.6125793	total: 20s	remaining: 3.01s
# 869:	learn: 0.6125080	total: 20s	remaining: 2.98s
# 870:	learn: 0.6124332	total: 20s	remaining: 2.96s
# 871:	learn: 0.6123582	total: 20s	remaining: 2.94s
# 872:	learn: 0.6122667	total: 20s	remaining: 2.92s
# 873:	learn: 0.6121634	total: 20.1s	remaining: 2.89s
# 874:	learn: 0.6120925	total: 20.1s	remaining: 2.87s
# 875:	learn: 0.6120190	total: 20.1s	remaining: 2.85s
# 876:	learn: 0.6119293	total: 20.1s	remaining: 2.82s
# 877:	learn: 0.6118471	total: 20.1s	remaining: 2.8s
# 878:	learn: 0.6117708	total: 20.2s	remaining: 2.78s
# 879:	learn: 0.6117106	total: 20.2s	remaining: 2.75s
# 880:	learn: 0.6116193	total: 20.2s	remaining: 2.73s
# 881:	learn: 0.6115357	total: 20.2s	remaining: 2.71s
# 882:	learn: 0.6114436	total: 20.3s	remaining: 2.68s
# 883:	learn: 0.6113610	total: 20.3s	remaining: 2.66s
# 884:	learn: 0.6113074	total: 20.3s	remaining: 2.64s
# 885:	learn: 0.6112192	total: 20.3s	remaining: 2.61s
# 886:	learn: 0.6111344	total: 20.3s	remaining: 2.59s
# 887:	learn: 0.6110303	total: 20.4s	remaining: 2.57s
# 888:	learn: 0.6109524	total: 20.4s	remaining: 2.54s
# 889:	learn: 0.6108946	total: 20.4s	remaining: 2.52s
# 890:	learn: 0.6108285	total: 20.4s	remaining: 2.5s
# 891:	learn: 0.6107404	total: 20.5s	remaining: 2.48s
# 892:	learn: 0.6106660	total: 20.5s	remaining: 2.45s
# 893:	learn: 0.6105832	total: 20.5s	remaining: 2.43s
# 894:	learn: 0.6104899	total: 20.5s	remaining: 2.41s
# 895:	learn: 0.6104079	total: 20.5s	remaining: 2.38s
# 896:	learn: 0.6103256	total: 20.6s	remaining: 2.36s
# 897:	learn: 0.6102405	total: 20.6s	remaining: 2.34s
# 898:	learn: 0.6101385	total: 20.6s	remaining: 2.31s
# 899:	learn: 0.6100680	total: 20.6s	remaining: 2.29s
# 900:	learn: 0.6099813	total: 20.7s	remaining: 2.27s
# 901:	learn: 0.6099000	total: 20.7s	remaining: 2.25s
# 902:	learn: 0.6098148	total: 20.7s	remaining: 2.22s
# 903:	learn: 0.6097423	total: 20.7s	remaining: 2.2s
# 904:	learn: 0.6096556	total: 20.7s	remaining: 2.18s
# 905:	learn: 0.6095643	total: 20.8s	remaining: 2.15s
# 906:	learn: 0.6094761	total: 20.8s	remaining: 2.13s
# 907:	learn: 0.6093928	total: 20.8s	remaining: 2.11s
# 908:	learn: 0.6093111	total: 20.8s	remaining: 2.08s
# 909:	learn: 0.6092293	total: 20.8s	remaining: 2.06s
# 910:	learn: 0.6091554	total: 20.9s	remaining: 2.04s
# 911:	learn: 0.6090635	total: 20.9s	remaining: 2.02s
# 912:	learn: 0.6089829	total: 20.9s	remaining: 1.99s
# 913:	learn: 0.6089019	total: 20.9s	remaining: 1.97s
# 914:	learn: 0.6088284	total: 21s	remaining: 1.95s
# 915:	learn: 0.6087392	total: 21s	remaining: 1.92s
# 916:	learn: 0.6086781	total: 21s	remaining: 1.9s
# 917:	learn: 0.6085959	total: 21s	remaining: 1.88s
# 918:	learn: 0.6085192	total: 21.1s	remaining: 1.85s
# 919:	learn: 0.6084394	total: 21.1s	remaining: 1.83s
# 920:	learn: 0.6083289	total: 21.1s	remaining: 1.81s
# 921:	learn: 0.6082334	total: 21.1s	remaining: 1.79s
# 922:	learn: 0.6081535	total: 21.1s	remaining: 1.76s
# 923:	learn: 0.6080748	total: 21.2s	remaining: 1.74s
# 924:	learn: 0.6079740	total: 21.2s	remaining: 1.72s
# 925:	learn: 0.6078818	total: 21.2s	remaining: 1.69s
# 926:	learn: 0.6078018	total: 21.2s	remaining: 1.67s
# 927:	learn: 0.6077036	total: 21.2s	remaining: 1.65s
# 928:	learn: 0.6076195	total: 21.3s	remaining: 1.63s
# 929:	learn: 0.6075504	total: 21.3s	remaining: 1.6s
# 930:	learn: 0.6074569	total: 21.3s	remaining: 1.58s
# 931:	learn: 0.6073985	total: 21.3s	remaining: 1.56s
# 932:	learn: 0.6073059	total: 21.4s	remaining: 1.53s
# 933:	learn: 0.6072428	total: 21.4s	remaining: 1.51s
# 934:	learn: 0.6071933	total: 21.4s	remaining: 1.49s
# 935:	learn: 0.6071240	total: 21.4s	remaining: 1.47s
# 936:	learn: 0.6070144	total: 21.5s	remaining: 1.44s
# 937:	learn: 0.6069159	total: 21.5s	remaining: 1.42s
# 938:	learn: 0.6068518	total: 21.5s	remaining: 1.4s
# 939:	learn: 0.6067581	total: 21.5s	remaining: 1.37s
# 940:	learn: 0.6066818	total: 21.5s	remaining: 1.35s
# 941:	learn: 0.6065977	total: 21.6s	remaining: 1.33s
# 942:	learn: 0.6064985	total: 21.6s	remaining: 1.3s
# 943:	learn: 0.6064018	total: 21.6s	remaining: 1.28s
# 944:	learn: 0.6063163	total: 21.6s	remaining: 1.26s
# 945:	learn: 0.6062253	total: 21.7s	remaining: 1.24s
# 946:	learn: 0.6061529	total: 21.7s	remaining: 1.21s
# 947:	learn: 0.6060807	total: 21.7s	remaining: 1.19s
# 948:	learn: 0.6060031	total: 21.7s	remaining: 1.17s
# 949:	learn: 0.6059451	total: 21.7s	remaining: 1.14s
# 950:	learn: 0.6058606	total: 21.8s	remaining: 1.12s
# 951:	learn: 0.6057611	total: 21.8s	remaining: 1.1s
# 952:	learn: 0.6056747	total: 21.8s	remaining: 1.07s
# 953:	learn: 0.6055848	total: 21.8s	remaining: 1.05s
# 954:	learn: 0.6055084	total: 21.9s	remaining: 1.03s
# 955:	learn: 0.6054344	total: 21.9s	remaining: 1.01s
# 956:	learn: 0.6053645	total: 21.9s	remaining: 985ms
# 957:	learn: 0.6053004	total: 21.9s	remaining: 962ms
# 958:	learn: 0.6052352	total: 22s	remaining: 940ms
# 959:	learn: 0.6051543	total: 22s	remaining: 917ms
# 960:	learn: 0.6050775	total: 22s	remaining: 894ms
# 961:	learn: 0.6050024	total: 22.1s	remaining: 872ms
# 962:	learn: 0.6049186	total: 22.1s	remaining: 849ms
# 963:	learn: 0.6048428	total: 22.1s	remaining: 826ms
# 964:	learn: 0.6047489	total: 22.1s	remaining: 803ms
# 965:	learn: 0.6046654	total: 22.2s	remaining: 780ms
# 966:	learn: 0.6045718	total: 22.2s	remaining: 757ms
# 967:	learn: 0.6044939	total: 22.2s	remaining: 734ms
# 968:	learn: 0.6044052	total: 22.2s	remaining: 711ms
# 969:	learn: 0.6043402	total: 22.2s	remaining: 688ms
# 970:	learn: 0.6042590	total: 22.3s	remaining: 665ms
# 971:	learn: 0.6041850	total: 22.3s	remaining: 642ms
# 972:	learn: 0.6041099	total: 22.3s	remaining: 619ms
# 973:	learn: 0.6040140	total: 22.3s	remaining: 596ms
# 974:	learn: 0.6039456	total: 22.4s	remaining: 573ms
# 975:	learn: 0.6038470	total: 22.4s	remaining: 550ms
# 976:	learn: 0.6037578	total: 22.4s	remaining: 527ms
# 977:	learn: 0.6036707	total: 22.4s	remaining: 504ms
# 978:	learn: 0.6035960	total: 22.4s	remaining: 481ms
# 979:	learn: 0.6035151	total: 22.5s	remaining: 459ms
# 980:	learn: 0.6034489	total: 22.5s	remaining: 436ms
# 981:	learn: 0.6033549	total: 22.5s	remaining: 413ms
# 982:	learn: 0.6032689	total: 22.5s	remaining: 390ms
# 983:	learn: 0.6032012	total: 22.6s	remaining: 367ms
# 984:	learn: 0.6031269	total: 22.6s	remaining: 344ms
# 985:	learn: 0.6030335	total: 22.6s	remaining: 321ms
# 986:	learn: 0.6029548	total: 22.6s	remaining: 298ms
# 987:	learn: 0.6028733	total: 22.6s	remaining: 275ms
# 988:	learn: 0.6027896	total: 22.7s	remaining: 252ms
# 989:	learn: 0.6027096	total: 22.7s	remaining: 229ms
# 990:	learn: 0.6026199	total: 22.7s	remaining: 206ms
# 991:	learn: 0.6025314	total: 22.7s	remaining: 183ms
# 992:	learn: 0.6024307	total: 22.8s	remaining: 160ms
# 993:	learn: 0.6023513	total: 22.8s	remaining: 138ms
# 994:	learn: 0.6022647	total: 22.8s	remaining: 115ms
# 995:	learn: 0.6021853	total: 22.8s	remaining: 91.7ms
# 996:	learn: 0.6020992	total: 22.9s	remaining: 68.8ms
# 997:	learn: 0.6020031	total: 22.9s	remaining: 45.8ms
# 998:	learn: 0.6019211	total: 22.9s	remaining: 22.9ms
# 999:	learn: 0.6018403	total: 22.9s	remaining: 0us
# Accuracy: 0.50
# Confusion Matrix:
#  [[5604 6319]
#  [5625 6452]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48     11923
#            1       0.51      0.53      0.52     12077
#
#     accuracy                           0.50     24000
#    macro avg       0.50      0.50      0.50     24000
# weighted avg       0.50      0.50      0.50     24000

# %% [markdown]
# Accuracy: The accuracy of the model is 0.50, which means it correctly predicted 50% of the total instances in the dataset.
#
# Confusion Matrix:
#
# For class 0, there are 5,604 true positives (TP) and 6,319 false negatives (FN).
# For class 1, there are 6,625 true positives (TP) and 6,452 false negatives (FN).
# The confusion matrix provides details about how the model's predictions compare to the actual class labels.
#
# Classification Report:
#
# For class 0:
#
# Precision: 0.50 (50% of predicted positives are correct)
# Recall: 0.47 (47% of actual positives are correctly predicted)
# F1-score: 0.48 (a balance between precision and recall)
# Support: 11,923 instances in class 0.
# For class 1:
#
# Precision: 0.51 (51% of predicted positives are correct)
# Recall: 0.53 (53% of actual positives are correctly predicted)
# F1-score: 0.52 (a balance between precision and recall)
# Support: 12,077 instances in class 1.
# Macro Average:
#
# Macro Average precision, recall, and F1-score represent the average values for all classes.
# In this case, both precision and recall are around 0.50, and the F1-score is also around 0.50.
# Weighted Average:
#
# Weighted Average precision, recall, and F1-score are weighted by the number of instances in each class.
# These values are also around 0.50, as they take into account the class imbalance.
